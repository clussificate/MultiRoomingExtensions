# %% [markdown]
# ## In this DOC, the linear retrun rate is used.

# %%
# -*- coding: utf-8 -*-
"""
@Created at 2022/7/2 15:38
@Author: Kurt
@file:uniform.py
@Desc:
"""
from collections import Counter
import numpy as np
import logging

logging.basicConfig()
logger = logging.getLogger("uniform")
logger.setLevel(logging.DEBUG)

EPSILON = 0.000001


def myround(num):
    num = num if abs(num) > EPSILON else 0
    return num


def get_return_probability(m, p):
    return m * p


def utility_tie_online(loc, c, con, m, p):
    """
    In this function, the tie is broken by assuming consumers buy online directly
    :param loc: value of theta
    """
    u_o = 1 / 2 * (loc - p) - 1 / 2 * (1 - get_return_probability(m, p)) * p - con
    u_s = 1 / 2 * (loc - p) - c
    if myround(u_o - u_s) >= 0:
        if myround(u_o) >= 0:
            return "o"
        else:
            return "l"
    else:
        if myround(u_s) >= 0:
            return "s"
        else:
            return "l"


def utility_tie_offline(loc, c, con, m, p):
    """
    In this function, the tie is broken by assuming consumers visit the store
    :param loc: value of theta
    """
    u_o = 1 / 2 * (loc - p) - 1 / 2 * (1 - get_return_probability(m, p)) * p - con
    u_s = 1 / 2 * (loc - p) - c
    if myround(u_o - u_s) > 0:
        if myround(u_o) >= 0:
            return "o"
        else:
            return "l"
    else:
        if myround(u_s) >= 0:
            return "s"
        else:
            return "l"


def get_demand(behaviors):
    total = len(behaviors)
    count = Counter(behaviors)
    alpha_o = count['o'] / total
    alpha_s = count['s'] / total
    alpha_l = count['l'] / total
    assert myround(alpha_o + alpha_s + alpha_l - 1) == 0

    return alpha_o, alpha_s


def simulate_behavior(consumers, c, con, m, p):
    # if consumers are indifferent between buying online directly and visiting the store,
    # we break the tie by maximizing the retailer's profit
    if myround(c - con - 1 / 2 * (1 - get_return_probability(m, p)) * p) == 0:
        behaviors_tie_online = [utility_tie_online(loc=consumer, c=c, con=con, m=m, p=p) for consumer in consumers]
        behaviors_tie_offline = [utility_tie_offline(loc=consumer, c=c, con=con, m=m, p=p) for consumer in consumers]

        return behaviors_tie_online, behaviors_tie_offline
    else:
        # if there is no tie, utility_tie_online and utility_tie_offline are equivalent.
        behaviors = [utility_tie_online(loc=consumer, c=c, con=con, m=m, p=p) for consumer in consumers]

        return behaviors


def cal_profit(m, p, cr, behaviors):
    alpha_o, alpha_s = get_demand(behaviors)
    online_profit = alpha_o * (1 / 2 * p + 1 / 2 * (
                (1 - get_return_probability(m=m, p=p)) * p - get_return_probability(m=m, p=p) * cr))  # w.p. 1/2, b=b_H.
    store_profit = alpha_s * 1 / 2 * p  # w.p. 1/2, b=b_H
    profit = 1 / 2 * store_profit + 1 / 2 * online_profit  # w.p. 1/2, a=a_H
    return profit

# %%
class uniform:

    def __init__(self, c, con, cr, return_prop, step=0.001, density=0.001):
        """
        :param c: offline shopping cost
        :param con: online shopping cost
        :param cr: retailer return cost
        :param m: return probability of direct online purchase
        :param step: step size of price
        :param density=0.001: density of consumers
        """
        self.p = 0
        self.profit = 0
        self.solve(c=c, con=con, cr=cr, return_prop=return_prop, step=step, density=density)

    def solve(self, c, con, cr, return_prop, step, density):
        consumers = np.arange(0, 1, density)

        optimal_profit = 0
        optimal_price = 0
        for p in np.arange(0.0001, 1, step):
            if isinstance(return_prop, str):
                m = 1 / (2 * p)
            else:
                m = return_prop
            logger.debug("current loop: p={:.3f}".format(p))
#             if myround(1 / 2 * m * p * p - 1 / 2 * p + c - con) == 0:
            if myround(c - con - 1/2*(1-get_return_probability(m, p))*p)==0:
                behaviors_tie_online, behaviors_tie_offline = simulate_behavior(consumers=consumers,
                                                                                c=c, con=con, m=m, p=p)
                profit_tie_online = cal_profit(m=m, p=p, cr=cr, behaviors=behaviors_tie_online)
                profit_tie_offline = cal_profit(m=m, p=p, cr=cr, behaviors=behaviors_tie_offline)
                profit = max(profit_tie_online, profit_tie_offline)
            else:
                behaviors = simulate_behavior(consumers=consumers, c=c, con=con, m=m, p=p)
                profit = cal_profit(m=m, p=p, cr=cr, behaviors=behaviors)

            if profit - optimal_profit > 0:
                optimal_profit = profit
                optimal_price = p
        self.p = optimal_price
        self.profit = optimal_profit

# %%
if __name__ == "__main__":
    c = 0.10
    cr = 0.32
    con = 0.05
    m = 1 / 4
    uniform_ins = uniform(c=c, con=con, cr=cr, m=m, step=0.001, density=0.001)
    print(uniform_ins.p, uniform_ins.profit)
# Out:
# DEBUG:uniform:current loop: p=0.000
# DEBUG:uniform:current loop: p=0.001
# DEBUG:uniform:current loop: p=0.002
# DEBUG:uniform:current loop: p=0.003
# DEBUG:uniform:current loop: p=0.004
# DEBUG:uniform:current loop: p=0.005
# DEBUG:uniform:current loop: p=0.006
# DEBUG:uniform:current loop: p=0.007
# DEBUG:uniform:current loop: p=0.008
# DEBUG:uniform:current loop: p=0.009
# DEBUG:uniform:current loop: p=0.010
# DEBUG:uniform:current loop: p=0.011
# DEBUG:uniform:current loop: p=0.012
# DEBUG:uniform:current loop: p=0.013
# DEBUG:uniform:current loop: p=0.014
# DEBUG:uniform:current loop: p=0.015
# DEBUG:uniform:current loop: p=0.016
# DEBUG:uniform:current loop: p=0.017
# DEBUG:uniform:current loop: p=0.018
# DEBUG:uniform:current loop: p=0.019
# DEBUG:uniform:current loop: p=0.020
# DEBUG:uniform:current loop: p=0.021
# DEBUG:uniform:current loop: p=0.022
# DEBUG:uniform:current loop: p=0.023
# DEBUG:uniform:current loop: p=0.024
# DEBUG:uniform:current loop: p=0.025
# DEBUG:uniform:current loop: p=0.026
# DEBUG:uniform:current loop: p=0.027
# DEBUG:uniform:current loop: p=0.028
# DEBUG:uniform:current loop: p=0.029
# DEBUG:uniform:current loop: p=0.030
# DEBUG:uniform:current loop: p=0.031
# DEBUG:uniform:current loop: p=0.032
# DEBUG:uniform:current loop: p=0.033
# DEBUG:uniform:current loop: p=0.034
# DEBUG:uniform:current loop: p=0.035
# DEBUG:uniform:current loop: p=0.036
# DEBUG:uniform:current loop: p=0.037
# DEBUG:uniform:current loop: p=0.038
# DEBUG:uniform:current loop: p=0.039
# DEBUG:uniform:current loop: p=0.040
# DEBUG:uniform:current loop: p=0.041
# DEBUG:uniform:current loop: p=0.042
# DEBUG:uniform:current loop: p=0.043
# DEBUG:uniform:current loop: p=0.044
# DEBUG:uniform:current loop: p=0.045
# DEBUG:uniform:current loop: p=0.046
# DEBUG:uniform:current loop: p=0.047
# DEBUG:uniform:current loop: p=0.048
# DEBUG:uniform:current loop: p=0.049
# DEBUG:uniform:current loop: p=0.050
# DEBUG:uniform:current loop: p=0.051
# DEBUG:uniform:current loop: p=0.052
# DEBUG:uniform:current loop: p=0.053
# DEBUG:uniform:current loop: p=0.054
# DEBUG:uniform:current loop: p=0.055
# DEBUG:uniform:current loop: p=0.056
# DEBUG:uniform:current loop: p=0.057
# DEBUG:uniform:current loop: p=0.058
# DEBUG:uniform:current loop: p=0.059
# DEBUG:uniform:current loop: p=0.060
# DEBUG:uniform:current loop: p=0.061
# DEBUG:uniform:current loop: p=0.062
# DEBUG:uniform:current loop: p=0.063
# DEBUG:uniform:current loop: p=0.064
# DEBUG:uniform:current loop: p=0.065
# DEBUG:uniform:current loop: p=0.066
# DEBUG:uniform:current loop: p=0.067
# DEBUG:uniform:current loop: p=0.068
# DEBUG:uniform:current loop: p=0.069
# DEBUG:uniform:current loop: p=0.070
# DEBUG:uniform:current loop: p=0.071
# DEBUG:uniform:current loop: p=0.072
# DEBUG:uniform:current loop: p=0.073
# DEBUG:uniform:current loop: p=0.074
# DEBUG:uniform:current loop: p=0.075
# DEBUG:uniform:current loop: p=0.076
# DEBUG:uniform:current loop: p=0.077
# DEBUG:uniform:current loop: p=0.078
# DEBUG:uniform:current loop: p=0.079
# DEBUG:uniform:current loop: p=0.080
# DEBUG:uniform:current loop: p=0.081
# DEBUG:uniform:current loop: p=0.082
# DEBUG:uniform:current loop: p=0.083
# DEBUG:uniform:current loop: p=0.084
# DEBUG:uniform:current loop: p=0.085
# DEBUG:uniform:current loop: p=0.086
# DEBUG:uniform:current loop: p=0.087
# DEBUG:uniform:current loop: p=0.088
# DEBUG:uniform:current loop: p=0.089
# DEBUG:uniform:current loop: p=0.090
# DEBUG:uniform:current loop: p=0.091
# DEBUG:uniform:current loop: p=0.092
# DEBUG:uniform:current loop: p=0.093
# DEBUG:uniform:current loop: p=0.094
# DEBUG:uniform:current loop: p=0.095
# DEBUG:uniform:current loop: p=0.096
# DEBUG:uniform:current loop: p=0.097
# DEBUG:uniform:current loop: p=0.098
# DEBUG:uniform:current loop: p=0.099
# DEBUG:uniform:current loop: p=0.100
# DEBUG:uniform:current loop: p=0.101
# DEBUG:uniform:current loop: p=0.102
# DEBUG:uniform:current loop: p=0.103
# DEBUG:uniform:current loop: p=0.104
# DEBUG:uniform:current loop: p=0.105
# DEBUG:uniform:current loop: p=0.106
# DEBUG:uniform:current loop: p=0.107
# DEBUG:uniform:current loop: p=0.108
# DEBUG:uniform:current loop: p=0.109
# DEBUG:uniform:current loop: p=0.110
# DEBUG:uniform:current loop: p=0.111
# DEBUG:uniform:current loop: p=0.112
# DEBUG:uniform:current loop: p=0.113
# DEBUG:uniform:current loop: p=0.114
# DEBUG:uniform:current loop: p=0.115
# DEBUG:uniform:current loop: p=0.116
# DEBUG:uniform:current loop: p=0.117
# DEBUG:uniform:current loop: p=0.118
# DEBUG:uniform:current loop: p=0.119
# DEBUG:uniform:current loop: p=0.120
# DEBUG:uniform:current loop: p=0.121
# DEBUG:uniform:current loop: p=0.122
# DEBUG:uniform:current loop: p=0.123
# DEBUG:uniform:current loop: p=0.124
# DEBUG:uniform:current loop: p=0.125
# DEBUG:uniform:current loop: p=0.126
# DEBUG:uniform:current loop: p=0.127
# DEBUG:uniform:current loop: p=0.128
# DEBUG:uniform:current loop: p=0.129
# DEBUG:uniform:current loop: p=0.130
# DEBUG:uniform:current loop: p=0.131
# DEBUG:uniform:current loop: p=0.132
# DEBUG:uniform:current loop: p=0.133
# DEBUG:uniform:current loop: p=0.134
# DEBUG:uniform:current loop: p=0.135
# DEBUG:uniform:current loop: p=0.136
# DEBUG:uniform:current loop: p=0.137
# DEBUG:uniform:current loop: p=0.138
# DEBUG:uniform:current loop: p=0.139
# DEBUG:uniform:current loop: p=0.140
# DEBUG:uniform:current loop: p=0.141
# DEBUG:uniform:current loop: p=0.142
# DEBUG:uniform:current loop: p=0.143
# DEBUG:uniform:current loop: p=0.144
# DEBUG:uniform:current loop: p=0.145
# DEBUG:uniform:current loop: p=0.146
# DEBUG:uniform:current loop: p=0.147
# DEBUG:uniform:current loop: p=0.148
# DEBUG:uniform:current loop: p=0.149
# DEBUG:uniform:current loop: p=0.150
# DEBUG:uniform:current loop: p=0.151
# DEBUG:uniform:current loop: p=0.152
# DEBUG:uniform:current loop: p=0.153
# DEBUG:uniform:current loop: p=0.154
# DEBUG:uniform:current loop: p=0.155
# DEBUG:uniform:current loop: p=0.156
# DEBUG:uniform:current loop: p=0.157
# DEBUG:uniform:current loop: p=0.158
# DEBUG:uniform:current loop: p=0.159
# DEBUG:uniform:current loop: p=0.160
# DEBUG:uniform:current loop: p=0.161
# DEBUG:uniform:current loop: p=0.162
# DEBUG:uniform:current loop: p=0.163
# DEBUG:uniform:current loop: p=0.164
# DEBUG:uniform:current loop: p=0.165
# DEBUG:uniform:current loop: p=0.166
# DEBUG:uniform:current loop: p=0.167
# DEBUG:uniform:current loop: p=0.168
# DEBUG:uniform:current loop: p=0.169
# DEBUG:uniform:current loop: p=0.170
# DEBUG:uniform:current loop: p=0.171
# DEBUG:uniform:current loop: p=0.172
# DEBUG:uniform:current loop: p=0.173
# DEBUG:uniform:current loop: p=0.174
# DEBUG:uniform:current loop: p=0.175
# DEBUG:uniform:current loop: p=0.176
# DEBUG:uniform:current loop: p=0.177
# DEBUG:uniform:current loop: p=0.178
# DEBUG:uniform:current loop: p=0.179
# DEBUG:uniform:current loop: p=0.180
# DEBUG:uniform:current loop: p=0.181
# DEBUG:uniform:current loop: p=0.182
# DEBUG:uniform:current loop: p=0.183
# DEBUG:uniform:current loop: p=0.184
# DEBUG:uniform:current loop: p=0.185
# DEBUG:uniform:current loop: p=0.186
# DEBUG:uniform:current loop: p=0.187
# DEBUG:uniform:current loop: p=0.188
# DEBUG:uniform:current loop: p=0.189
# DEBUG:uniform:current loop: p=0.190
# DEBUG:uniform:current loop: p=0.191
# DEBUG:uniform:current loop: p=0.192
# DEBUG:uniform:current loop: p=0.193
# DEBUG:uniform:current loop: p=0.194
# DEBUG:uniform:current loop: p=0.195
# DEBUG:uniform:current loop: p=0.196
# DEBUG:uniform:current loop: p=0.197
# DEBUG:uniform:current loop: p=0.198
# DEBUG:uniform:current loop: p=0.199
# DEBUG:uniform:current loop: p=0.200
# DEBUG:uniform:current loop: p=0.201
# DEBUG:uniform:current loop: p=0.202
# DEBUG:uniform:current loop: p=0.203
# DEBUG:uniform:current loop: p=0.204
# DEBUG:uniform:current loop: p=0.205
# DEBUG:uniform:current loop: p=0.206
# DEBUG:uniform:current loop: p=0.207
# DEBUG:uniform:current loop: p=0.208
# DEBUG:uniform:current loop: p=0.209
# DEBUG:uniform:current loop: p=0.210
# DEBUG:uniform:current loop: p=0.211
# DEBUG:uniform:current loop: p=0.212
# DEBUG:uniform:current loop: p=0.213
# DEBUG:uniform:current loop: p=0.214
# DEBUG:uniform:current loop: p=0.215
# DEBUG:uniform:current loop: p=0.216
# DEBUG:uniform:current loop: p=0.217
# DEBUG:uniform:current loop: p=0.218
# DEBUG:uniform:current loop: p=0.219
# DEBUG:uniform:current loop: p=0.220
# DEBUG:uniform:current loop: p=0.221
# DEBUG:uniform:current loop: p=0.222
# DEBUG:uniform:current loop: p=0.223
# DEBUG:uniform:current loop: p=0.224
# DEBUG:uniform:current loop: p=0.225
# DEBUG:uniform:current loop: p=0.226
# DEBUG:uniform:current loop: p=0.227
# DEBUG:uniform:current loop: p=0.228
# DEBUG:uniform:current loop: p=0.229
# DEBUG:uniform:current loop: p=0.230
# DEBUG:uniform:current loop: p=0.231
# DEBUG:uniform:current loop: p=0.232
# DEBUG:uniform:current loop: p=0.233
# DEBUG:uniform:current loop: p=0.234
# DEBUG:uniform:current loop: p=0.235
# DEBUG:uniform:current loop: p=0.236
# DEBUG:uniform:current loop: p=0.237
# DEBUG:uniform:current loop: p=0.238
# DEBUG:uniform:current loop: p=0.239
# DEBUG:uniform:current loop: p=0.240
# DEBUG:uniform:current loop: p=0.241
# DEBUG:uniform:current loop: p=0.242
# DEBUG:uniform:current loop: p=0.243
# DEBUG:uniform:current loop: p=0.244
# DEBUG:uniform:current loop: p=0.245
# DEBUG:uniform:current loop: p=0.246
# DEBUG:uniform:current loop: p=0.247
# DEBUG:uniform:current loop: p=0.248
# DEBUG:uniform:current loop: p=0.249
# DEBUG:uniform:current loop: p=0.250
# DEBUG:uniform:current loop: p=0.251
# DEBUG:uniform:current loop: p=0.252
# DEBUG:uniform:current loop: p=0.253
# DEBUG:uniform:current loop: p=0.254
# DEBUG:uniform:current loop: p=0.255
# DEBUG:uniform:current loop: p=0.256
# DEBUG:uniform:current loop: p=0.257
# DEBUG:uniform:current loop: p=0.258
# DEBUG:uniform:current loop: p=0.259
# DEBUG:uniform:current loop: p=0.260
# DEBUG:uniform:current loop: p=0.261
# DEBUG:uniform:current loop: p=0.262
# DEBUG:uniform:current loop: p=0.263
# DEBUG:uniform:current loop: p=0.264
# DEBUG:uniform:current loop: p=0.265
# DEBUG:uniform:current loop: p=0.266
# DEBUG:uniform:current loop: p=0.267
# DEBUG:uniform:current loop: p=0.268
# DEBUG:uniform:current loop: p=0.269
# DEBUG:uniform:current loop: p=0.270
# DEBUG:uniform:current loop: p=0.271
# DEBUG:uniform:current loop: p=0.272
# DEBUG:uniform:current loop: p=0.273
# DEBUG:uniform:current loop: p=0.274
# DEBUG:uniform:current loop: p=0.275
# DEBUG:uniform:current loop: p=0.276
# DEBUG:uniform:current loop: p=0.277
# DEBUG:uniform:current loop: p=0.278
# DEBUG:uniform:current loop: p=0.279
# DEBUG:uniform:current loop: p=0.280
# DEBUG:uniform:current loop: p=0.281
# DEBUG:uniform:current loop: p=0.282
# DEBUG:uniform:current loop: p=0.283
# DEBUG:uniform:current loop: p=0.284
# DEBUG:uniform:current loop: p=0.285
# DEBUG:uniform:current loop: p=0.286
# DEBUG:uniform:current loop: p=0.287
# DEBUG:uniform:current loop: p=0.288
# DEBUG:uniform:current loop: p=0.289
# DEBUG:uniform:current loop: p=0.290
# DEBUG:uniform:current loop: p=0.291
# DEBUG:uniform:current loop: p=0.292
# DEBUG:uniform:current loop: p=0.293
# DEBUG:uniform:current loop: p=0.294
# DEBUG:uniform:current loop: p=0.295
# DEBUG:uniform:current loop: p=0.296
# DEBUG:uniform:current loop: p=0.297
# DEBUG:uniform:current loop: p=0.298
# DEBUG:uniform:current loop: p=0.299
# DEBUG:uniform:current loop: p=0.300
# DEBUG:uniform:current loop: p=0.301
# DEBUG:uniform:current loop: p=0.302
# DEBUG:uniform:current loop: p=0.303
# DEBUG:uniform:current loop: p=0.304
# DEBUG:uniform:current loop: p=0.305
# DEBUG:uniform:current loop: p=0.306
# DEBUG:uniform:current loop: p=0.307
# DEBUG:uniform:current loop: p=0.308
# DEBUG:uniform:current loop: p=0.309
# DEBUG:uniform:current loop: p=0.310
# DEBUG:uniform:current loop: p=0.311
# DEBUG:uniform:current loop: p=0.312
# DEBUG:uniform:current loop: p=0.313
# DEBUG:uniform:current loop: p=0.314
# DEBUG:uniform:current loop: p=0.315
# DEBUG:uniform:current loop: p=0.316
# DEBUG:uniform:current loop: p=0.317
# DEBUG:uniform:current loop: p=0.318
# DEBUG:uniform:current loop: p=0.319
# DEBUG:uniform:current loop: p=0.320
# DEBUG:uniform:current loop: p=0.321
# DEBUG:uniform:current loop: p=0.322
# DEBUG:uniform:current loop: p=0.323
# DEBUG:uniform:current loop: p=0.324
# DEBUG:uniform:current loop: p=0.325
# DEBUG:uniform:current loop: p=0.326
# DEBUG:uniform:current loop: p=0.327
# DEBUG:uniform:current loop: p=0.328
# DEBUG:uniform:current loop: p=0.329
# DEBUG:uniform:current loop: p=0.330
# DEBUG:uniform:current loop: p=0.331
# DEBUG:uniform:current loop: p=0.332
# DEBUG:uniform:current loop: p=0.333
# DEBUG:uniform:current loop: p=0.334
# DEBUG:uniform:current loop: p=0.335
# DEBUG:uniform:current loop: p=0.336
# DEBUG:uniform:current loop: p=0.337
# DEBUG:uniform:current loop: p=0.338
# DEBUG:uniform:current loop: p=0.339
# DEBUG:uniform:current loop: p=0.340
# DEBUG:uniform:current loop: p=0.341
# DEBUG:uniform:current loop: p=0.342
# DEBUG:uniform:current loop: p=0.343
# DEBUG:uniform:current loop: p=0.344
# DEBUG:uniform:current loop: p=0.345
# DEBUG:uniform:current loop: p=0.346
# DEBUG:uniform:current loop: p=0.347
# DEBUG:uniform:current loop: p=0.348
# DEBUG:uniform:current loop: p=0.349
# DEBUG:uniform:current loop: p=0.350
# DEBUG:uniform:current loop: p=0.351
# DEBUG:uniform:current loop: p=0.352
# DEBUG:uniform:current loop: p=0.353
# DEBUG:uniform:current loop: p=0.354
# DEBUG:uniform:current loop: p=0.355
# DEBUG:uniform:current loop: p=0.356
# DEBUG:uniform:current loop: p=0.357
# DEBUG:uniform:current loop: p=0.358
# DEBUG:uniform:current loop: p=0.359
# DEBUG:uniform:current loop: p=0.360
# DEBUG:uniform:current loop: p=0.361
# DEBUG:uniform:current loop: p=0.362
# DEBUG:uniform:current loop: p=0.363
# DEBUG:uniform:current loop: p=0.364
# DEBUG:uniform:current loop: p=0.365
# DEBUG:uniform:current loop: p=0.366
# DEBUG:uniform:current loop: p=0.367
# DEBUG:uniform:current loop: p=0.368
# DEBUG:uniform:current loop: p=0.369
# DEBUG:uniform:current loop: p=0.370
# DEBUG:uniform:current loop: p=0.371
# DEBUG:uniform:current loop: p=0.372
# DEBUG:uniform:current loop: p=0.373
# DEBUG:uniform:current loop: p=0.374
# DEBUG:uniform:current loop: p=0.375
# DEBUG:uniform:current loop: p=0.376
# DEBUG:uniform:current loop: p=0.377
# DEBUG:uniform:current loop: p=0.378
# DEBUG:uniform:current loop: p=0.379
# DEBUG:uniform:current loop: p=0.380
# DEBUG:uniform:current loop: p=0.381
# DEBUG:uniform:current loop: p=0.382
# DEBUG:uniform:current loop: p=0.383
# DEBUG:uniform:current loop: p=0.384
# DEBUG:uniform:current loop: p=0.385
# DEBUG:uniform:current loop: p=0.386
# DEBUG:uniform:current loop: p=0.387
# DEBUG:uniform:current loop: p=0.388
# DEBUG:uniform:current loop: p=0.389
# DEBUG:uniform:current loop: p=0.390
# DEBUG:uniform:current loop: p=0.391
# DEBUG:uniform:current loop: p=0.392
# DEBUG:uniform:current loop: p=0.393
# DEBUG:uniform:current loop: p=0.394
# DEBUG:uniform:current loop: p=0.395
# DEBUG:uniform:current loop: p=0.396
# DEBUG:uniform:current loop: p=0.397
# DEBUG:uniform:current loop: p=0.398
# DEBUG:uniform:current loop: p=0.399
# DEBUG:uniform:current loop: p=0.400
# DEBUG:uniform:current loop: p=0.401
# DEBUG:uniform:current loop: p=0.402
# DEBUG:uniform:current loop: p=0.403
# DEBUG:uniform:current loop: p=0.404
# DEBUG:uniform:current loop: p=0.405
# DEBUG:uniform:current loop: p=0.406
# DEBUG:uniform:current loop: p=0.407
# DEBUG:uniform:current loop: p=0.408
# DEBUG:uniform:current loop: p=0.409
# DEBUG:uniform:current loop: p=0.410
# DEBUG:uniform:current loop: p=0.411
# DEBUG:uniform:current loop: p=0.412
# DEBUG:uniform:current loop: p=0.413
# DEBUG:uniform:current loop: p=0.414
# DEBUG:uniform:current loop: p=0.415
# DEBUG:uniform:current loop: p=0.416
# DEBUG:uniform:current loop: p=0.417
# DEBUG:uniform:current loop: p=0.418
# DEBUG:uniform:current loop: p=0.419
# DEBUG:uniform:current loop: p=0.420
# DEBUG:uniform:current loop: p=0.421
# DEBUG:uniform:current loop: p=0.422
# DEBUG:uniform:current loop: p=0.423
# DEBUG:uniform:current loop: p=0.424
# DEBUG:uniform:current loop: p=0.425
# DEBUG:uniform:current loop: p=0.426
# DEBUG:uniform:current loop: p=0.427
# DEBUG:uniform:current loop: p=0.428
# DEBUG:uniform:current loop: p=0.429
# DEBUG:uniform:current loop: p=0.430
# DEBUG:uniform:current loop: p=0.431
# DEBUG:uniform:current loop: p=0.432
# DEBUG:uniform:current loop: p=0.433
# DEBUG:uniform:current loop: p=0.434
# DEBUG:uniform:current loop: p=0.435
# DEBUG:uniform:current loop: p=0.436
# DEBUG:uniform:current loop: p=0.437
# DEBUG:uniform:current loop: p=0.438
# DEBUG:uniform:current loop: p=0.439
# DEBUG:uniform:current loop: p=0.440
# DEBUG:uniform:current loop: p=0.441
# DEBUG:uniform:current loop: p=0.442
# DEBUG:uniform:current loop: p=0.443
# DEBUG:uniform:current loop: p=0.444
# DEBUG:uniform:current loop: p=0.445
# DEBUG:uniform:current loop: p=0.446
# DEBUG:uniform:current loop: p=0.447
# DEBUG:uniform:current loop: p=0.448
# DEBUG:uniform:current loop: p=0.449
# DEBUG:uniform:current loop: p=0.450
# DEBUG:uniform:current loop: p=0.451
# DEBUG:uniform:current loop: p=0.452
# DEBUG:uniform:current loop: p=0.453
# DEBUG:uniform:current loop: p=0.454
# DEBUG:uniform:current loop: p=0.455
# DEBUG:uniform:current loop: p=0.456
# DEBUG:uniform:current loop: p=0.457
# DEBUG:uniform:current loop: p=0.458
# DEBUG:uniform:current loop: p=0.459
# DEBUG:uniform:current loop: p=0.460
# DEBUG:uniform:current loop: p=0.461
# DEBUG:uniform:current loop: p=0.462
# DEBUG:uniform:current loop: p=0.463
# DEBUG:uniform:current loop: p=0.464
# DEBUG:uniform:current loop: p=0.465
# DEBUG:uniform:current loop: p=0.466
# DEBUG:uniform:current loop: p=0.467
# DEBUG:uniform:current loop: p=0.468
# DEBUG:uniform:current loop: p=0.469
# DEBUG:uniform:current loop: p=0.470
# DEBUG:uniform:current loop: p=0.471
# DEBUG:uniform:current loop: p=0.472
# DEBUG:uniform:current loop: p=0.473
# DEBUG:uniform:current loop: p=0.474
# DEBUG:uniform:current loop: p=0.475
# DEBUG:uniform:current loop: p=0.476
# DEBUG:uniform:current loop: p=0.477
# DEBUG:uniform:current loop: p=0.478
# DEBUG:uniform:current loop: p=0.479
# DEBUG:uniform:current loop: p=0.480
# DEBUG:uniform:current loop: p=0.481
# DEBUG:uniform:current loop: p=0.482
# DEBUG:uniform:current loop: p=0.483
# DEBUG:uniform:current loop: p=0.484
# DEBUG:uniform:current loop: p=0.485
# DEBUG:uniform:current loop: p=0.486
# DEBUG:uniform:current loop: p=0.487
# DEBUG:uniform:current loop: p=0.488
# DEBUG:uniform:current loop: p=0.489
# DEBUG:uniform:current loop: p=0.490
# DEBUG:uniform:current loop: p=0.491
# DEBUG:uniform:current loop: p=0.492
# DEBUG:uniform:current loop: p=0.493
# DEBUG:uniform:current loop: p=0.494
# DEBUG:uniform:current loop: p=0.495
# DEBUG:uniform:current loop: p=0.496
# DEBUG:uniform:current loop: p=0.497
# DEBUG:uniform:current loop: p=0.498
# DEBUG:uniform:current loop: p=0.499
# DEBUG:uniform:current loop: p=0.500
# DEBUG:uniform:current loop: p=0.501
# DEBUG:uniform:current loop: p=0.502
# DEBUG:uniform:current loop: p=0.503
# DEBUG:uniform:current loop: p=0.504
# DEBUG:uniform:current loop: p=0.505
# DEBUG:uniform:current loop: p=0.506
# DEBUG:uniform:current loop: p=0.507
# DEBUG:uniform:current loop: p=0.508
# DEBUG:uniform:current loop: p=0.509
# DEBUG:uniform:current loop: p=0.510
# DEBUG:uniform:current loop: p=0.511
# DEBUG:uniform:current loop: p=0.512
# DEBUG:uniform:current loop: p=0.513
# DEBUG:uniform:current loop: p=0.514
# DEBUG:uniform:current loop: p=0.515
# DEBUG:uniform:current loop: p=0.516
# DEBUG:uniform:current loop: p=0.517
# DEBUG:uniform:current loop: p=0.518
# DEBUG:uniform:current loop: p=0.519
# DEBUG:uniform:current loop: p=0.520
# DEBUG:uniform:current loop: p=0.521
# DEBUG:uniform:current loop: p=0.522
# DEBUG:uniform:current loop: p=0.523
# DEBUG:uniform:current loop: p=0.524
# DEBUG:uniform:current loop: p=0.525
# DEBUG:uniform:current loop: p=0.526
# DEBUG:uniform:current loop: p=0.527
# DEBUG:uniform:current loop: p=0.528
# DEBUG:uniform:current loop: p=0.529
# DEBUG:uniform:current loop: p=0.530
# DEBUG:uniform:current loop: p=0.531
# DEBUG:uniform:current loop: p=0.532
# DEBUG:uniform:current loop: p=0.533
# DEBUG:uniform:current loop: p=0.534
# DEBUG:uniform:current loop: p=0.535
# DEBUG:uniform:current loop: p=0.536
# DEBUG:uniform:current loop: p=0.537
# DEBUG:uniform:current loop: p=0.538
# DEBUG:uniform:current loop: p=0.539
# DEBUG:uniform:current loop: p=0.540
# DEBUG:uniform:current loop: p=0.541
# DEBUG:uniform:current loop: p=0.542
# DEBUG:uniform:current loop: p=0.543
# DEBUG:uniform:current loop: p=0.544
# DEBUG:uniform:current loop: p=0.545
# DEBUG:uniform:current loop: p=0.546
# DEBUG:uniform:current loop: p=0.547
# DEBUG:uniform:current loop: p=0.548
# DEBUG:uniform:current loop: p=0.549
# DEBUG:uniform:current loop: p=0.550
# DEBUG:uniform:current loop: p=0.551
# DEBUG:uniform:current loop: p=0.552
# DEBUG:uniform:current loop: p=0.553
# DEBUG:uniform:current loop: p=0.554
# DEBUG:uniform:current loop: p=0.555
# DEBUG:uniform:current loop: p=0.556
# DEBUG:uniform:current loop: p=0.557
# DEBUG:uniform:current loop: p=0.558
# DEBUG:uniform:current loop: p=0.559
# DEBUG:uniform:current loop: p=0.560
# DEBUG:uniform:current loop: p=0.561
# DEBUG:uniform:current loop: p=0.562
# DEBUG:uniform:current loop: p=0.563
# DEBUG:uniform:current loop: p=0.564
# DEBUG:uniform:current loop: p=0.565
# DEBUG:uniform:current loop: p=0.566
# DEBUG:uniform:current loop: p=0.567
# DEBUG:uniform:current loop: p=0.568
# DEBUG:uniform:current loop: p=0.569
# DEBUG:uniform:current loop: p=0.570
# DEBUG:uniform:current loop: p=0.571
# DEBUG:uniform:current loop: p=0.572
# DEBUG:uniform:current loop: p=0.573
# DEBUG:uniform:current loop: p=0.574
# DEBUG:uniform:current loop: p=0.575
# DEBUG:uniform:current loop: p=0.576
# DEBUG:uniform:current loop: p=0.577
# DEBUG:uniform:current loop: p=0.578
# DEBUG:uniform:current loop: p=0.579
# DEBUG:uniform:current loop: p=0.580
# DEBUG:uniform:current loop: p=0.581
# DEBUG:uniform:current loop: p=0.582
# DEBUG:uniform:current loop: p=0.583
# DEBUG:uniform:current loop: p=0.584
# DEBUG:uniform:current loop: p=0.585
# DEBUG:uniform:current loop: p=0.586
# DEBUG:uniform:current loop: p=0.587
# DEBUG:uniform:current loop: p=0.588
# DEBUG:uniform:current loop: p=0.589
# DEBUG:uniform:current loop: p=0.590
# DEBUG:uniform:current loop: p=0.591
# DEBUG:uniform:current loop: p=0.592
# DEBUG:uniform:current loop: p=0.593
# DEBUG:uniform:current loop: p=0.594
# DEBUG:uniform:current loop: p=0.595
# DEBUG:uniform:current loop: p=0.596
# DEBUG:uniform:current loop: p=0.597
# DEBUG:uniform:current loop: p=0.598
# DEBUG:uniform:current loop: p=0.599
# DEBUG:uniform:current loop: p=0.600
# DEBUG:uniform:current loop: p=0.601
# DEBUG:uniform:current loop: p=0.602
# DEBUG:uniform:current loop: p=0.603
# DEBUG:uniform:current loop: p=0.604
# DEBUG:uniform:current loop: p=0.605
# DEBUG:uniform:current loop: p=0.606
# DEBUG:uniform:current loop: p=0.607
# DEBUG:uniform:current loop: p=0.608
# DEBUG:uniform:current loop: p=0.609
# DEBUG:uniform:current loop: p=0.610
# DEBUG:uniform:current loop: p=0.611
# DEBUG:uniform:current loop: p=0.612
# DEBUG:uniform:current loop: p=0.613
# DEBUG:uniform:current loop: p=0.614
# DEBUG:uniform:current loop: p=0.615
# DEBUG:uniform:current loop: p=0.616
# DEBUG:uniform:current loop: p=0.617
# DEBUG:uniform:current loop: p=0.618
# DEBUG:uniform:current loop: p=0.619
# DEBUG:uniform:current loop: p=0.620
# DEBUG:uniform:current loop: p=0.621
# DEBUG:uniform:current loop: p=0.622
# DEBUG:uniform:current loop: p=0.623
# DEBUG:uniform:current loop: p=0.624
# DEBUG:uniform:current loop: p=0.625
# DEBUG:uniform:current loop: p=0.626
# DEBUG:uniform:current loop: p=0.627
# DEBUG:uniform:current loop: p=0.628
# DEBUG:uniform:current loop: p=0.629
# DEBUG:uniform:current loop: p=0.630
# DEBUG:uniform:current loop: p=0.631
# DEBUG:uniform:current loop: p=0.632
# DEBUG:uniform:current loop: p=0.633
# DEBUG:uniform:current loop: p=0.634
# DEBUG:uniform:current loop: p=0.635
# DEBUG:uniform:current loop: p=0.636
# DEBUG:uniform:current loop: p=0.637
# DEBUG:uniform:current loop: p=0.638
# DEBUG:uniform:current loop: p=0.639
# DEBUG:uniform:current loop: p=0.640
# DEBUG:uniform:current loop: p=0.641
# DEBUG:uniform:current loop: p=0.642
# DEBUG:uniform:current loop: p=0.643
# DEBUG:uniform:current loop: p=0.644
# DEBUG:uniform:current loop: p=0.645
# DEBUG:uniform:current loop: p=0.646
# DEBUG:uniform:current loop: p=0.647
# DEBUG:uniform:current loop: p=0.648
# DEBUG:uniform:current loop: p=0.649
# DEBUG:uniform:current loop: p=0.650
# DEBUG:uniform:current loop: p=0.651
# DEBUG:uniform:current loop: p=0.652
# DEBUG:uniform:current loop: p=0.653
# DEBUG:uniform:current loop: p=0.654
# DEBUG:uniform:current loop: p=0.655
# DEBUG:uniform:current loop: p=0.656
# DEBUG:uniform:current loop: p=0.657
# DEBUG:uniform:current loop: p=0.658
# DEBUG:uniform:current loop: p=0.659
# DEBUG:uniform:current loop: p=0.660
# DEBUG:uniform:current loop: p=0.661
# DEBUG:uniform:current loop: p=0.662
# DEBUG:uniform:current loop: p=0.663
# DEBUG:uniform:current loop: p=0.664
# DEBUG:uniform:current loop: p=0.665
# DEBUG:uniform:current loop: p=0.666
# DEBUG:uniform:current loop: p=0.667
# DEBUG:uniform:current loop: p=0.668
# DEBUG:uniform:current loop: p=0.669
# DEBUG:uniform:current loop: p=0.670
# DEBUG:uniform:current loop: p=0.671
# DEBUG:uniform:current loop: p=0.672
# DEBUG:uniform:current loop: p=0.673
# DEBUG:uniform:current loop: p=0.674
# DEBUG:uniform:current loop: p=0.675
# DEBUG:uniform:current loop: p=0.676
# DEBUG:uniform:current loop: p=0.677
# DEBUG:uniform:current loop: p=0.678
# DEBUG:uniform:current loop: p=0.679
# DEBUG:uniform:current loop: p=0.680
# DEBUG:uniform:current loop: p=0.681
# DEBUG:uniform:current loop: p=0.682
# DEBUG:uniform:current loop: p=0.683
# DEBUG:uniform:current loop: p=0.684
# DEBUG:uniform:current loop: p=0.685
# DEBUG:uniform:current loop: p=0.686
# DEBUG:uniform:current loop: p=0.687
# DEBUG:uniform:current loop: p=0.688
# DEBUG:uniform:current loop: p=0.689
# DEBUG:uniform:current loop: p=0.690
# DEBUG:uniform:current loop: p=0.691
# DEBUG:uniform:current loop: p=0.692
# DEBUG:uniform:current loop: p=0.693
# DEBUG:uniform:current loop: p=0.694
# DEBUG:uniform:current loop: p=0.695
# DEBUG:uniform:current loop: p=0.696
# DEBUG:uniform:current loop: p=0.697
# DEBUG:uniform:current loop: p=0.698
# DEBUG:uniform:current loop: p=0.699
# DEBUG:uniform:current loop: p=0.700
# DEBUG:uniform:current loop: p=0.701
# DEBUG:uniform:current loop: p=0.702
# DEBUG:uniform:current loop: p=0.703
# DEBUG:uniform:current loop: p=0.704
# DEBUG:uniform:current loop: p=0.705
# DEBUG:uniform:current loop: p=0.706
# DEBUG:uniform:current loop: p=0.707
# DEBUG:uniform:current loop: p=0.708
# DEBUG:uniform:current loop: p=0.709
# DEBUG:uniform:current loop: p=0.710
# DEBUG:uniform:current loop: p=0.711
# DEBUG:uniform:current loop: p=0.712
# DEBUG:uniform:current loop: p=0.713
# DEBUG:uniform:current loop: p=0.714
# DEBUG:uniform:current loop: p=0.715
# DEBUG:uniform:current loop: p=0.716
# DEBUG:uniform:current loop: p=0.717
# DEBUG:uniform:current loop: p=0.718
# DEBUG:uniform:current loop: p=0.719
# DEBUG:uniform:current loop: p=0.720
# DEBUG:uniform:current loop: p=0.721
# DEBUG:uniform:current loop: p=0.722
# DEBUG:uniform:current loop: p=0.723
# DEBUG:uniform:current loop: p=0.724
# DEBUG:uniform:current loop: p=0.725
# DEBUG:uniform:current loop: p=0.726
# DEBUG:uniform:current loop: p=0.727
# DEBUG:uniform:current loop: p=0.728
# DEBUG:uniform:current loop: p=0.729
# DEBUG:uniform:current loop: p=0.730
# DEBUG:uniform:current loop: p=0.731
# DEBUG:uniform:current loop: p=0.732
# DEBUG:uniform:current loop: p=0.733
# DEBUG:uniform:current loop: p=0.734
# DEBUG:uniform:current loop: p=0.735
# DEBUG:uniform:current loop: p=0.736
# DEBUG:uniform:current loop: p=0.737
# DEBUG:uniform:current loop: p=0.738
# DEBUG:uniform:current loop: p=0.739
# DEBUG:uniform:current loop: p=0.740
# DEBUG:uniform:current loop: p=0.741
# DEBUG:uniform:current loop: p=0.742
# DEBUG:uniform:current loop: p=0.743
# DEBUG:uniform:current loop: p=0.744
# DEBUG:uniform:current loop: p=0.745
# DEBUG:uniform:current loop: p=0.746
# DEBUG:uniform:current loop: p=0.747
# DEBUG:uniform:current loop: p=0.748
# DEBUG:uniform:current loop: p=0.749
# DEBUG:uniform:current loop: p=0.750
# DEBUG:uniform:current loop: p=0.751
# DEBUG:uniform:current loop: p=0.752
# DEBUG:uniform:current loop: p=0.753
# DEBUG:uniform:current loop: p=0.754
# DEBUG:uniform:current loop: p=0.755
# DEBUG:uniform:current loop: p=0.756
# DEBUG:uniform:current loop: p=0.757
# DEBUG:uniform:current loop: p=0.758
# DEBUG:uniform:current loop: p=0.759
# DEBUG:uniform:current loop: p=0.760
# DEBUG:uniform:current loop: p=0.761
# DEBUG:uniform:current loop: p=0.762
# DEBUG:uniform:current loop: p=0.763
# DEBUG:uniform:current loop: p=0.764
# DEBUG:uniform:current loop: p=0.765
# DEBUG:uniform:current loop: p=0.766
# DEBUG:uniform:current loop: p=0.767
# DEBUG:uniform:current loop: p=0.768
# DEBUG:uniform:current loop: p=0.769
# DEBUG:uniform:current loop: p=0.770
# DEBUG:uniform:current loop: p=0.771
# DEBUG:uniform:current loop: p=0.772
# DEBUG:uniform:current loop: p=0.773
# DEBUG:uniform:current loop: p=0.774
# DEBUG:uniform:current loop: p=0.775
# DEBUG:uniform:current loop: p=0.776
# DEBUG:uniform:current loop: p=0.777
# DEBUG:uniform:current loop: p=0.778
# DEBUG:uniform:current loop: p=0.779
# DEBUG:uniform:current loop: p=0.780
# DEBUG:uniform:current loop: p=0.781
# DEBUG:uniform:current loop: p=0.782
# DEBUG:uniform:current loop: p=0.783
# DEBUG:uniform:current loop: p=0.784
# DEBUG:uniform:current loop: p=0.785
# DEBUG:uniform:current loop: p=0.786
# DEBUG:uniform:current loop: p=0.787
# DEBUG:uniform:current loop: p=0.788
# DEBUG:uniform:current loop: p=0.789
# DEBUG:uniform:current loop: p=0.790
# DEBUG:uniform:current loop: p=0.791
# DEBUG:uniform:current loop: p=0.792
# DEBUG:uniform:current loop: p=0.793
# DEBUG:uniform:current loop: p=0.794
# DEBUG:uniform:current loop: p=0.795
# DEBUG:uniform:current loop: p=0.796
# DEBUG:uniform:current loop: p=0.797
# DEBUG:uniform:current loop: p=0.798
# DEBUG:uniform:current loop: p=0.799
# DEBUG:uniform:current loop: p=0.800
# DEBUG:uniform:current loop: p=0.801
# DEBUG:uniform:current loop: p=0.802
# DEBUG:uniform:current loop: p=0.803
# DEBUG:uniform:current loop: p=0.804
# DEBUG:uniform:current loop: p=0.805
# DEBUG:uniform:current loop: p=0.806
# DEBUG:uniform:current loop: p=0.807
# DEBUG:uniform:current loop: p=0.808
# DEBUG:uniform:current loop: p=0.809
# DEBUG:uniform:current loop: p=0.810
# DEBUG:uniform:current loop: p=0.811
# DEBUG:uniform:current loop: p=0.812
# DEBUG:uniform:current loop: p=0.813
# DEBUG:uniform:current loop: p=0.814
# DEBUG:uniform:current loop: p=0.815
# DEBUG:uniform:current loop: p=0.816
# DEBUG:uniform:current loop: p=0.817
# DEBUG:uniform:current loop: p=0.818
# DEBUG:uniform:current loop: p=0.819
# DEBUG:uniform:current loop: p=0.820
# DEBUG:uniform:current loop: p=0.821
# DEBUG:uniform:current loop: p=0.822
# DEBUG:uniform:current loop: p=0.823
# DEBUG:uniform:current loop: p=0.824
# DEBUG:uniform:current loop: p=0.825
# DEBUG:uniform:current loop: p=0.826
# DEBUG:uniform:current loop: p=0.827
# DEBUG:uniform:current loop: p=0.828
# DEBUG:uniform:current loop: p=0.829
# DEBUG:uniform:current loop: p=0.830
# DEBUG:uniform:current loop: p=0.831
# DEBUG:uniform:current loop: p=0.832
# DEBUG:uniform:current loop: p=0.833
# DEBUG:uniform:current loop: p=0.834
# DEBUG:uniform:current loop: p=0.835
# DEBUG:uniform:current loop: p=0.836
# DEBUG:uniform:current loop: p=0.837
# DEBUG:uniform:current loop: p=0.838
# DEBUG:uniform:current loop: p=0.839
# DEBUG:uniform:current loop: p=0.840
# DEBUG:uniform:current loop: p=0.841
# DEBUG:uniform:current loop: p=0.842
# DEBUG:uniform:current loop: p=0.843
# DEBUG:uniform:current loop: p=0.844
# DEBUG:uniform:current loop: p=0.845
# DEBUG:uniform:current loop: p=0.846
# DEBUG:uniform:current loop: p=0.847
# DEBUG:uniform:current loop: p=0.848
# DEBUG:uniform:current loop: p=0.849
# DEBUG:uniform:current loop: p=0.850
# DEBUG:uniform:current loop: p=0.851
# DEBUG:uniform:current loop: p=0.852
# DEBUG:uniform:current loop: p=0.853
# DEBUG:uniform:current loop: p=0.854
# DEBUG:uniform:current loop: p=0.855
# DEBUG:uniform:current loop: p=0.856
# DEBUG:uniform:current loop: p=0.857
# DEBUG:uniform:current loop: p=0.858
# DEBUG:uniform:current loop: p=0.859
# DEBUG:uniform:current loop: p=0.860
# DEBUG:uniform:current loop: p=0.861
# DEBUG:uniform:current loop: p=0.862
# DEBUG:uniform:current loop: p=0.863
# DEBUG:uniform:current loop: p=0.864
# DEBUG:uniform:current loop: p=0.865
# DEBUG:uniform:current loop: p=0.866
# DEBUG:uniform:current loop: p=0.867
# DEBUG:uniform:current loop: p=0.868
# DEBUG:uniform:current loop: p=0.869
# DEBUG:uniform:current loop: p=0.870
# DEBUG:uniform:current loop: p=0.871
# DEBUG:uniform:current loop: p=0.872
# DEBUG:uniform:current loop: p=0.873
# DEBUG:uniform:current loop: p=0.874
# DEBUG:uniform:current loop: p=0.875
# DEBUG:uniform:current loop: p=0.876
# DEBUG:uniform:current loop: p=0.877
# DEBUG:uniform:current loop: p=0.878
# DEBUG:uniform:current loop: p=0.879
# DEBUG:uniform:current loop: p=0.880
# DEBUG:uniform:current loop: p=0.881
# DEBUG:uniform:current loop: p=0.882
# DEBUG:uniform:current loop: p=0.883
# DEBUG:uniform:current loop: p=0.884
# DEBUG:uniform:current loop: p=0.885
# DEBUG:uniform:current loop: p=0.886
# DEBUG:uniform:current loop: p=0.887
# DEBUG:uniform:current loop: p=0.888
# DEBUG:uniform:current loop: p=0.889
# DEBUG:uniform:current loop: p=0.890
# DEBUG:uniform:current loop: p=0.891
# DEBUG:uniform:current loop: p=0.892
# DEBUG:uniform:current loop: p=0.893
# DEBUG:uniform:current loop: p=0.894
# DEBUG:uniform:current loop: p=0.895
# DEBUG:uniform:current loop: p=0.896
# DEBUG:uniform:current loop: p=0.897
# DEBUG:uniform:current loop: p=0.898
# DEBUG:uniform:current loop: p=0.899
# DEBUG:uniform:current loop: p=0.900
# DEBUG:uniform:current loop: p=0.901
# DEBUG:uniform:current loop: p=0.902
# DEBUG:uniform:current loop: p=0.903
# DEBUG:uniform:current loop: p=0.904
# DEBUG:uniform:current loop: p=0.905
# DEBUG:uniform:current loop: p=0.906
# DEBUG:uniform:current loop: p=0.907
# DEBUG:uniform:current loop: p=0.908
# DEBUG:uniform:current loop: p=0.909
# DEBUG:uniform:current loop: p=0.910
# DEBUG:uniform:current loop: p=0.911
# DEBUG:uniform:current loop: p=0.912
# DEBUG:uniform:current loop: p=0.913
# DEBUG:uniform:current loop: p=0.914
# DEBUG:uniform:current loop: p=0.915
# DEBUG:uniform:current loop: p=0.916
# DEBUG:uniform:current loop: p=0.917
# DEBUG:uniform:current loop: p=0.918
# DEBUG:uniform:current loop: p=0.919
# DEBUG:uniform:current loop: p=0.920
# DEBUG:uniform:current loop: p=0.921
# DEBUG:uniform:current loop: p=0.922
# DEBUG:uniform:current loop: p=0.923
# DEBUG:uniform:current loop: p=0.924
# DEBUG:uniform:current loop: p=0.925
# DEBUG:uniform:current loop: p=0.926
# DEBUG:uniform:current loop: p=0.927
# DEBUG:uniform:current loop: p=0.928
# DEBUG:uniform:current loop: p=0.929
# DEBUG:uniform:current loop: p=0.930
# DEBUG:uniform:current loop: p=0.931
# DEBUG:uniform:current loop: p=0.932
# DEBUG:uniform:current loop: p=0.933
# DEBUG:uniform:current loop: p=0.934
# DEBUG:uniform:current loop: p=0.935
# DEBUG:uniform:current loop: p=0.936
# DEBUG:uniform:current loop: p=0.937
# DEBUG:uniform:current loop: p=0.938
# DEBUG:uniform:current loop: p=0.939
# DEBUG:uniform:current loop: p=0.940
# DEBUG:uniform:current loop: p=0.941
# DEBUG:uniform:current loop: p=0.942
# DEBUG:uniform:current loop: p=0.943
# DEBUG:uniform:current loop: p=0.944
# DEBUG:uniform:current loop: p=0.945
# DEBUG:uniform:current loop: p=0.946
# DEBUG:uniform:current loop: p=0.947
# DEBUG:uniform:current loop: p=0.948
# DEBUG:uniform:current loop: p=0.949
# DEBUG:uniform:current loop: p=0.950
# DEBUG:uniform:current loop: p=0.951
# DEBUG:uniform:current loop: p=0.952
# DEBUG:uniform:current loop: p=0.953
# DEBUG:uniform:current loop: p=0.954
# DEBUG:uniform:current loop: p=0.955
# DEBUG:uniform:current loop: p=0.956
# DEBUG:uniform:current loop: p=0.957
# DEBUG:uniform:current loop: p=0.958
# DEBUG:uniform:current loop: p=0.959
# DEBUG:uniform:current loop: p=0.960
# DEBUG:uniform:current loop: p=0.961
# DEBUG:uniform:current loop: p=0.962
# DEBUG:uniform:current loop: p=0.963
# DEBUG:uniform:current loop: p=0.964
# DEBUG:uniform:current loop: p=0.965
# DEBUG:uniform:current loop: p=0.966
# DEBUG:uniform:current loop: p=0.967
# DEBUG:uniform:current loop: p=0.968
# DEBUG:uniform:current loop: p=0.969
# DEBUG:uniform:current loop: p=0.970
# DEBUG:uniform:current loop: p=0.971
# DEBUG:uniform:current loop: p=0.972
# DEBUG:uniform:current loop: p=0.973
# DEBUG:uniform:current loop: p=0.974
# DEBUG:uniform:current loop: p=0.975
# DEBUG:uniform:current loop: p=0.976
# DEBUG:uniform:current loop: p=0.977
# DEBUG:uniform:current loop: p=0.978
# DEBUG:uniform:current loop: p=0.979
# DEBUG:uniform:current loop: p=0.980
# DEBUG:uniform:current loop: p=0.981
# DEBUG:uniform:current loop: p=0.982
# DEBUG:uniform:current loop: p=0.983
# DEBUG:uniform:current loop: p=0.984
# DEBUG:uniform:current loop: p=0.985
# DEBUG:uniform:current loop: p=0.986
# DEBUG:uniform:current loop: p=0.987
# DEBUG:uniform:current loop: p=0.988
# DEBUG:uniform:current loop: p=0.989
# DEBUG:uniform:current loop: p=0.990
# DEBUG:uniform:current loop: p=0.991
# DEBUG:uniform:current loop: p=0.992
# DEBUG:uniform:current loop: p=0.993
# DEBUG:uniform:current loop: p=0.994
# DEBUG:uniform:current loop: p=0.995
# DEBUG:uniform:current loop: p=0.996
# DEBUG:uniform:current loop: p=0.997
# DEBUG:uniform:current loop: p=0.998
# DEBUG:uniform:current loop: p=0.999
# 0.4 0.04000000000000001
