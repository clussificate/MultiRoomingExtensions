# %%
# -*- coding: utf-8 -*-
"""
@Created at 2022/7/3 13:07
@Author: Kurt
@file:dual.py
@Desc:
"""
from collections import Counter
import numpy as np
import logging
import ray
import matplotlib.pyplot as plt

logging.basicConfig()
logger = logging.getLogger("uniform")
logger.setLevel(logging.DEBUG)

EPSILON = 0.000001

# %%
def myround(num):
    num = num if abs(num) > EPSILON else 0
    return num


def get_return_probability(m,pon):
    return m*pon
    

def utility_tie_online(loc, c, con, m, pon, poff):
    """
    In this function, the tie is broken by assuming consumers buy online directly
    :param loc: value of theta
    """
    u_o = 1 / 2 * (loc - pon) - 1 / 2 *  (1-get_return_probability(m=m, pon=pon)) * pon - con
    u_s = 1 / 2 * (loc - poff) - c
    if myround(u_o - u_s) >= 0:
        if myround(u_o) >= 0:
            return "o"
        else:
            return "l"
    else:
        if myround(u_s) >= 0:
            return "s"
        else:
            return "l"


def utility_tie_offline(loc, c, con, m, pon, poff):
    """
    In this function, the tie is broken by assuming consumers visit the store
    :param loc: value of theta
    """
    u_o = 1 / 2 * (loc - pon) - 1 / 2 *  (1-get_return_probability(m=m, pon=pon)) * pon - con
    u_s = 1 / 2 * (loc - poff) - c
    if myround(u_o - u_s) > 0:
        if myround(u_o) >= 0:
            return "o"
        else:
            return "l"
    else:
        if myround(u_s) >= 0:
            return "s"
        else:
            return "l"


def get_demand(behaviors):
    total = len(behaviors)
    count = Counter(behaviors)
    alpha_o = count['o'] / total
    alpha_s = count['s'] / total
    alpha_l = count['l'] / total
    assert myround(alpha_o + alpha_s + alpha_l - 1) == 0

    return alpha_o, alpha_s


def simulate_behavior(consumers, c, con, m, pon, poff):
    # if consumers are indifferent between buying online directly and visiting the store,
    # we break the tie by maximizing the retailer's profit
    if myround(c - 1/2*con - 1/2*(1-get_return_probability(m=m, pon=pon))*pon) == 0:
        behaviors_tie_online = [utility_tie_online(loc=consumer, c=c, con=con,
                                                   m=m, pon=pon, poff=poff) for consumer in consumers]
        behaviors_tie_offline = [utility_tie_offline(loc=consumer, c=c, con=con,
                                                     m=m, pon=pon, poff=poff) for consumer in consumers]

        return behaviors_tie_online, behaviors_tie_offline
    else:
        # if there is no tie, utility_tie_online and utility_tie_offline are equivalent.
        behaviors = [utility_tie_online(loc=consumer, c=c, con=con, m=m, pon=pon, poff=poff) for consumer in consumers]

        return behaviors


def cal_profit(m, pon, poff, cr, behaviors):
    alpha_o, alpha_s = get_demand(behaviors)
    logger.debug("current demand: alpha_o {:.3f}, alpha_s {:.3f}, return probability:{:.3f}".format(
        alpha_o, alpha_s, m * pon))
    online_profit = alpha_o * (1 / 2 * pon + 1 / 2 * (
        (1 - get_return_probability(m=m, pon=pon)) * pon - get_return_probability(m=m, pon=pon) * cr))  # w.p. 1/2, b=b_H.
    store_profit = alpha_s * 1 / 2 * poff  # w.p. 1/2, b=b_H
    logger.debug("current demand: online_profit {:.5f}, store_profit {:.5f}".format(online_profit, store_profit))
    profit = 1 / 2 * store_profit + 1 / 2 * online_profit  # w.p. 1/2, a=a_H
    return profit

# %%
class dual:
    def __init__(self, c, con, cr, return_prop, step=0.001, density=0.001):
        self.pon = 0
        self.poff = 0
        self.profit = 0
        self.solve(c=c, con=con, cr=cr, return_prop=return_prop, step=step, density=density)

    def solve(self, c, con, cr, return_prop, step, density):
        consumers = np.arange(0, 1, density)
        optimal_profit = 0
        optimal_pon = 0
        for pon in np.arange(0.0001, 1, step):
            poff = pon + con
            if isinstance(return_prop, str):
                m = 1 / (2 * pon)
            else:
                m = return_prop
#             logger.debug("current m: {:.3f}, pon: {:.3f}".format(m, pon))
            if myround(c - 1/2*con - 1/2*(1-get_return_probability(m=m, pon=pon))*pon) == 0:
                behaviors_tie_online, behaviors_tie_offline = simulate_behavior(consumers=consumers,
                                                                                c=c, con=con, m=m, pon=pon, poff=poff)
                profit_tie_online = cal_profit(m=m, pon=pon, poff=poff, cr=cr, behaviors=behaviors_tie_online)
                profit_tie_offline = cal_profit(m=m, pon=pon, poff=poff, cr=cr, behaviors=behaviors_tie_offline)
                profit = max(profit_tie_online, profit_tie_offline)
            else:
                behaviors = simulate_behavior(consumers=consumers, c=c, con=con, m=m, pon=pon, poff=poff)
                profit = cal_profit(m=m, pon=pon, poff=poff, cr=cr, behaviors=behaviors)

            logger.debug("current loop: pon={:.3f}, poff={:.3f}, profit={:.5f}".format(pon, poff, profit))
            logger.debug("-------"*10)
            if profit - optimal_profit > 0:
                optimal_profit = profit
                optimal_pon = pon
        self.pon = optimal_pon
        self.poff = optimal_pon + con
        self.profit = optimal_profit

# %% [markdown]
# ## Main test

# %%
c=0.145
cr = 0.5
con = 0.1
step = 0.001
density = 0.005
return_prop = 0.131 # if this is a string, it means that we set m=1/(2*pon), which degrades to the baseline model.
dual_ins = dual(c=c, con=con, return_prop=return_prop, cr=cr, step=0.005, density=0.0001)
# Out:
# DEBUG:uniform:current demand: alpha_o 0.800, alpha_s 0.000, return probability:0.000
# DEBUG:uniform:current demand: online_profit 0.00008, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.000, poff=0.100, profit=0.00004
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.790, alpha_s 0.000, return probability:0.001
# DEBUG:uniform:current demand: online_profit 0.00389, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.005, poff=0.105, profit=0.00195
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.780, alpha_s 0.000, return probability:0.001
# DEBUG:uniform:current demand: online_profit 0.00761, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.010, poff=0.110, profit=0.00381
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.770, alpha_s 0.000, return probability:0.002
# DEBUG:uniform:current demand: online_profit 0.01123, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.015, poff=0.115, profit=0.00562
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.760, alpha_s 0.000, return probability:0.003
# DEBUG:uniform:current demand: online_profit 0.01475, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.020, poff=0.120, profit=0.00738
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.750, alpha_s 0.000, return probability:0.003
# DEBUG:uniform:current demand: online_profit 0.01817, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.025, poff=0.125, profit=0.00909
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.740, alpha_s 0.000, return probability:0.004
# DEBUG:uniform:current demand: online_profit 0.02150, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.030, poff=0.130, profit=0.01075
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.730, alpha_s 0.000, return probability:0.005
# DEBUG:uniform:current demand: online_profit 0.02472, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.035, poff=0.135, profit=0.01236
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.720, alpha_s 0.000, return probability:0.005
# DEBUG:uniform:current demand: online_profit 0.02785, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.040, poff=0.140, profit=0.01393
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.710, alpha_s 0.000, return probability:0.006
# DEBUG:uniform:current demand: online_profit 0.03088, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.045, poff=0.145, profit=0.01544
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.700, alpha_s 0.000, return probability:0.007
# DEBUG:uniform:current demand: online_profit 0.03381, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.050, poff=0.150, profit=0.01691
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.690, alpha_s 0.000, return probability:0.007
# DEBUG:uniform:current demand: online_profit 0.03664, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.055, poff=0.155, profit=0.01832
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.680, alpha_s 0.000, return probability:0.008
# DEBUG:uniform:current demand: online_profit 0.03938, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.060, poff=0.160, profit=0.01969
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.670, alpha_s 0.000, return probability:0.009
# DEBUG:uniform:current demand: online_profit 0.04202, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.065, poff=0.165, profit=0.02101
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.660, alpha_s 0.000, return probability:0.009
# DEBUG:uniform:current demand: online_profit 0.04457, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.070, poff=0.170, profit=0.02228
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.650, alpha_s 0.000, return probability:0.010
# DEBUG:uniform:current demand: online_profit 0.04701, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.075, poff=0.175, profit=0.02351
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.641, alpha_s 0.000, return probability:0.010
# DEBUG:uniform:current demand: online_profit 0.04936, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.080, poff=0.180, profit=0.02468
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.631, alpha_s 0.000, return probability:0.011
# DEBUG:uniform:current demand: online_profit 0.05162, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.085, poff=0.185, profit=0.02581
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.621, alpha_s 0.000, return probability:0.012
# DEBUG:uniform:current demand: online_profit 0.05377, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.090, poff=0.190, profit=0.02689
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.611, alpha_s 0.000, return probability:0.012
# DEBUG:uniform:current demand: online_profit 0.05583, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.095, poff=0.195, profit=0.02792
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.601, alpha_s 0.000, return probability:0.013
# DEBUG:uniform:current demand: online_profit 0.05781, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.100, poff=0.200, profit=0.02890
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.591, alpha_s 0.000, return probability:0.014
# DEBUG:uniform:current demand: online_profit 0.05967, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.105, poff=0.205, profit=0.02984
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.581, alpha_s 0.000, return probability:0.014
# DEBUG:uniform:current demand: online_profit 0.06144, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.110, poff=0.210, profit=0.03072
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.572, alpha_s 0.000, return probability:0.015
# DEBUG:uniform:current demand: online_profit 0.06313, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.115, poff=0.215, profit=0.03156
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.562, alpha_s 0.000, return probability:0.016
# DEBUG:uniform:current demand: online_profit 0.06471, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.120, poff=0.220, profit=0.03235
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.552, alpha_s 0.000, return probability:0.016
# DEBUG:uniform:current demand: online_profit 0.06620, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.125, poff=0.225, profit=0.03310
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.542, alpha_s 0.000, return probability:0.017
# DEBUG:uniform:current demand: online_profit 0.06760, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.130, poff=0.230, profit=0.03380
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.532, alpha_s 0.000, return probability:0.018
# DEBUG:uniform:current demand: online_profit 0.06890, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.135, poff=0.235, profit=0.03445
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.522, alpha_s 0.000, return probability:0.018
# DEBUG:uniform:current demand: online_profit 0.07011, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.140, poff=0.240, profit=0.03505
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.512, alpha_s 0.000, return probability:0.019
# DEBUG:uniform:current demand: online_profit 0.07122, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.145, poff=0.245, profit=0.03561
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.503, alpha_s 0.000, return probability:0.020
# DEBUG:uniform:current demand: online_profit 0.07224, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.150, poff=0.250, profit=0.03612
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.493, alpha_s 0.000, return probability:0.020
# DEBUG:uniform:current demand: online_profit 0.07317, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.155, poff=0.255, profit=0.03658
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.483, alpha_s 0.000, return probability:0.021
# DEBUG:uniform:current demand: online_profit 0.07400, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.160, poff=0.260, profit=0.03700
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.473, alpha_s 0.000, return probability:0.022
# DEBUG:uniform:current demand: online_profit 0.07474, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.165, poff=0.265, profit=0.03737
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.464, alpha_s 0.000, return probability:0.022
# DEBUG:uniform:current demand: online_profit 0.07538, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.170, poff=0.270, profit=0.03769
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.454, alpha_s 0.000, return probability:0.023
# DEBUG:uniform:current demand: online_profit 0.07595, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.175, poff=0.275, profit=0.03797
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.444, alpha_s 0.000, return probability:0.024
# DEBUG:uniform:current demand: online_profit 0.07640, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.180, poff=0.280, profit=0.03820
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.434, alpha_s 0.000, return probability:0.024
# DEBUG:uniform:current demand: online_profit 0.07676, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.185, poff=0.285, profit=0.03838
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.424, alpha_s 0.000, return probability:0.025
# DEBUG:uniform:current demand: online_profit 0.07705, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.190, poff=0.290, profit=0.03852
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.415, return probability:0.026
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06122
# DEBUG:uniform:current loop: pon=0.195, poff=0.295, profit=0.03061
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.410, return probability:0.026
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06151
# DEBUG:uniform:current loop: pon=0.200, poff=0.300, profit=0.03075
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.405, return probability:0.027
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06177
# DEBUG:uniform:current loop: pon=0.205, poff=0.305, profit=0.03088
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.400, return probability:0.028
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06200
# DEBUG:uniform:current loop: pon=0.210, poff=0.310, profit=0.03100
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.395, return probability:0.028
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06222
# DEBUG:uniform:current loop: pon=0.215, poff=0.315, profit=0.03111
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.390, return probability:0.029
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06240
# DEBUG:uniform:current loop: pon=0.220, poff=0.320, profit=0.03120
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.385, return probability:0.029
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06257
# DEBUG:uniform:current loop: pon=0.225, poff=0.325, profit=0.03128
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.380, return probability:0.030
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06270
# DEBUG:uniform:current loop: pon=0.230, poff=0.330, profit=0.03135
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.375, return probability:0.031
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06281
# DEBUG:uniform:current loop: pon=0.235, poff=0.335, profit=0.03141
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.370, return probability:0.031
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06290
# DEBUG:uniform:current loop: pon=0.240, poff=0.340, profit=0.03145
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.365, return probability:0.032
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06296
# DEBUG:uniform:current loop: pon=0.245, poff=0.345, profit=0.03148
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.360, return probability:0.033
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06300
# DEBUG:uniform:current loop: pon=0.250, poff=0.350, profit=0.03150
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.355, return probability:0.033
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06301
# DEBUG:uniform:current loop: pon=0.255, poff=0.355, profit=0.03151
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.350, return probability:0.034
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06300
# DEBUG:uniform:current loop: pon=0.260, poff=0.360, profit=0.03150
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.345, return probability:0.035
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06296
# DEBUG:uniform:current loop: pon=0.265, poff=0.365, profit=0.03148
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.340, return probability:0.035
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06290
# DEBUG:uniform:current loop: pon=0.270, poff=0.370, profit=0.03145
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.335, return probability:0.036
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06281
# DEBUG:uniform:current loop: pon=0.275, poff=0.375, profit=0.03141
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.330, return probability:0.037
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06270
# DEBUG:uniform:current loop: pon=0.280, poff=0.380, profit=0.03135
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.325, return probability:0.037
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06256
# DEBUG:uniform:current loop: pon=0.285, poff=0.385, profit=0.03128
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.320, return probability:0.038
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06240
# DEBUG:uniform:current loop: pon=0.290, poff=0.390, profit=0.03120
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.315, return probability:0.039
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06221
# DEBUG:uniform:current loop: pon=0.295, poff=0.395, profit=0.03110
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.310, return probability:0.039
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06200
# DEBUG:uniform:current loop: pon=0.300, poff=0.400, profit=0.03100
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.305, return probability:0.040
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06176
# DEBUG:uniform:current loop: pon=0.305, poff=0.405, profit=0.03088
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.300, return probability:0.041
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06149
# DEBUG:uniform:current loop: pon=0.310, poff=0.410, profit=0.03075
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.295, return probability:0.041
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06121
# DEBUG:uniform:current loop: pon=0.315, poff=0.415, profit=0.03060
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.290, return probability:0.042
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06089
# DEBUG:uniform:current loop: pon=0.320, poff=0.420, profit=0.03045
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.285, return probability:0.043
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06056
# DEBUG:uniform:current loop: pon=0.325, poff=0.425, profit=0.03028
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.280, return probability:0.043
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06019
# DEBUG:uniform:current loop: pon=0.330, poff=0.430, profit=0.03010
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.275, return probability:0.044
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.05980
# DEBUG:uniform:current loop: pon=0.335, poff=0.435, profit=0.02990
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.270, return probability:0.045
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.05939
# DEBUG:uniform:current loop: pon=0.340, poff=0.440, profit=0.02970
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.265, return probability:0.045
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.05895
# DEBUG:uniform:current loop: pon=0.345, poff=0.445, profit=0.02948
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.260, return probability:0.046
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.05849
# DEBUG:uniform:current loop: pon=0.350, poff=0.450, profit=0.02925
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.255, return probability:0.047
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.05800
# DEBUG:uniform:current loop: pon=0.355, poff=0.455, profit=0.02900
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.250, return probability:0.047
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.05749
# DEBUG:uniform:current loop: pon=0.360, poff=0.460, profit=0.02874
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.245, return probability:0.048
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.05695
# DEBUG:uniform:current loop: pon=0.365, poff=0.465, profit=0.02848
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.240, return probability:0.048
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.05639
# DEBUG:uniform:current loop: pon=0.370, poff=0.470, profit=0.02819
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.235, return probability:0.049
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.05580
# DEBUG:uniform:current loop: pon=0.375, poff=0.475, profit=0.02790
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.230, return probability:0.050
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.05519
# DEBUG:uniform:current loop: pon=0.380, poff=0.480, profit=0.02759
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.225, return probability:0.050
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.05455
# DEBUG:uniform:current loop: pon=0.385, poff=0.485, profit=0.02727
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.220, return probability:0.051
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.05389
# DEBUG:uniform:current loop: pon=0.390, poff=0.490, profit=0.02694
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.215, return probability:0.052
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.05320
# DEBUG:uniform:current loop: pon=0.395, poff=0.495, profit=0.02660
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.210, return probability:0.052
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.05249
# DEBUG:uniform:current loop: pon=0.400, poff=0.500, profit=0.02624
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.205, return probability:0.053
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.05175
# DEBUG:uniform:current loop: pon=0.405, poff=0.505, profit=0.02587
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.200, return probability:0.054
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.05098
# DEBUG:uniform:current loop: pon=0.410, poff=0.510, profit=0.02549
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.195, return probability:0.054
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.05020
# DEBUG:uniform:current loop: pon=0.415, poff=0.515, profit=0.02510
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.190, return probability:0.055
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.04938
# DEBUG:uniform:current loop: pon=0.420, poff=0.520, profit=0.02469
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.185, return probability:0.056
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.04855
# DEBUG:uniform:current loop: pon=0.425, poff=0.525, profit=0.02427
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.180, return probability:0.056
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.04768
# DEBUG:uniform:current loop: pon=0.430, poff=0.530, profit=0.02384
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.175, return probability:0.057
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.04679
# DEBUG:uniform:current loop: pon=0.435, poff=0.535, profit=0.02340
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.170, return probability:0.058
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.04588
# DEBUG:uniform:current loop: pon=0.440, poff=0.540, profit=0.02294
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.165, return probability:0.058
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.04494
# DEBUG:uniform:current loop: pon=0.445, poff=0.545, profit=0.02247
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.160, return probability:0.059
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.04398
# DEBUG:uniform:current loop: pon=0.450, poff=0.550, profit=0.02199
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.155, return probability:0.060
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.04299
# DEBUG:uniform:current loop: pon=0.455, poff=0.555, profit=0.02150
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.150, return probability:0.060
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.04198
# DEBUG:uniform:current loop: pon=0.460, poff=0.560, profit=0.02099
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.145, return probability:0.061
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.04094
# DEBUG:uniform:current loop: pon=0.465, poff=0.565, profit=0.02047
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.140, return probability:0.062
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.03988
# DEBUG:uniform:current loop: pon=0.470, poff=0.570, profit=0.01994
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.135, return probability:0.062
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.03879
# DEBUG:uniform:current loop: pon=0.475, poff=0.575, profit=0.01940
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.130, return probability:0.063
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.03768
# DEBUG:uniform:current loop: pon=0.480, poff=0.580, profit=0.01884
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.125, return probability:0.064
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.03654
# DEBUG:uniform:current loop: pon=0.485, poff=0.585, profit=0.01827
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.120, return probability:0.064
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.03538
# DEBUG:uniform:current loop: pon=0.490, poff=0.590, profit=0.01769
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.115, return probability:0.065
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.03419
# DEBUG:uniform:current loop: pon=0.495, poff=0.595, profit=0.01709
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.110, return probability:0.066
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.03298
# DEBUG:uniform:current loop: pon=0.500, poff=0.600, profit=0.01649
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.105, return probability:0.066
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.03174
# DEBUG:uniform:current loop: pon=0.505, poff=0.605, profit=0.01587
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.100, return probability:0.067
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.03047
# DEBUG:uniform:current loop: pon=0.510, poff=0.610, profit=0.01524
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.095, return probability:0.067
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.02919
# DEBUG:uniform:current loop: pon=0.515, poff=0.615, profit=0.01459
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.090, return probability:0.068
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.02787
# DEBUG:uniform:current loop: pon=0.520, poff=0.620, profit=0.01394
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.085, return probability:0.069
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.02654
# DEBUG:uniform:current loop: pon=0.525, poff=0.625, profit=0.01327
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.080, return probability:0.069
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.02517
# DEBUG:uniform:current loop: pon=0.530, poff=0.630, profit=0.01259
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.075, return probability:0.070
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.02378
# DEBUG:uniform:current loop: pon=0.535, poff=0.635, profit=0.01189
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.070, return probability:0.071
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.02237
# DEBUG:uniform:current loop: pon=0.540, poff=0.640, profit=0.01119
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.065, return probability:0.071
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.02093
# DEBUG:uniform:current loop: pon=0.545, poff=0.645, profit=0.01047
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.060, return probability:0.072
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.01947
# DEBUG:uniform:current loop: pon=0.550, poff=0.650, profit=0.00974
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.055, return probability:0.073
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.01798
# DEBUG:uniform:current loop: pon=0.555, poff=0.655, profit=0.00899
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.050, return probability:0.073
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.01647
# DEBUG:uniform:current loop: pon=0.560, poff=0.660, profit=0.00823
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.045, return probability:0.074
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.01493
# DEBUG:uniform:current loop: pon=0.565, poff=0.665, profit=0.00747
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.040, return probability:0.075
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.01337
# DEBUG:uniform:current loop: pon=0.570, poff=0.670, profit=0.00668
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.035, return probability:0.075
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.01178
# DEBUG:uniform:current loop: pon=0.575, poff=0.675, profit=0.00589
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.030, return probability:0.076
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.01017
# DEBUG:uniform:current loop: pon=0.580, poff=0.680, profit=0.00508
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.025, return probability:0.077
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00853
# DEBUG:uniform:current loop: pon=0.585, poff=0.685, profit=0.00426
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.020, return probability:0.077
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00687
# DEBUG:uniform:current loop: pon=0.590, poff=0.690, profit=0.00343
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.015, return probability:0.078
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00518
# DEBUG:uniform:current loop: pon=0.595, poff=0.695, profit=0.00259
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.010, return probability:0.079
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00347
# DEBUG:uniform:current loop: pon=0.600, poff=0.700, profit=0.00173
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.005, return probability:0.079
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00173
# DEBUG:uniform:current loop: pon=0.605, poff=0.705, profit=0.00086
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.080
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.610, poff=0.710, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.081
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.615, poff=0.715, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.081
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.620, poff=0.720, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.082
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.625, poff=0.725, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.083
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.630, poff=0.730, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.083
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.635, poff=0.735, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.084
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.640, poff=0.740, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.085
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.645, poff=0.745, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.085
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.650, poff=0.750, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.086
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.655, poff=0.755, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.086
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.660, poff=0.760, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.087
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.665, poff=0.765, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.088
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.670, poff=0.770, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.088
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.675, poff=0.775, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.089
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.680, poff=0.780, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.090
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.685, poff=0.785, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.090
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.690, poff=0.790, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.091
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.695, poff=0.795, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.092
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.700, poff=0.800, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.092
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.705, poff=0.805, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.093
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.710, poff=0.810, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.094
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.715, poff=0.815, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.094
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.720, poff=0.820, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.095
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.725, poff=0.825, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.096
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.730, poff=0.830, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.096
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.735, poff=0.835, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.097
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.740, poff=0.840, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.098
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.745, poff=0.845, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.098
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.750, poff=0.850, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.099
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.755, poff=0.855, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.100
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.760, poff=0.860, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.100
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.765, poff=0.865, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.101
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.770, poff=0.870, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.102
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.775, poff=0.875, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.102
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.780, poff=0.880, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.103
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.785, poff=0.885, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.104
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.790, poff=0.890, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.104
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.795, poff=0.895, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.105
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.800, poff=0.900, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.105
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.805, poff=0.905, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.106
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.810, poff=0.910, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.107
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.815, poff=0.915, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.107
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.820, poff=0.920, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.108
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.825, poff=0.925, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.109
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.830, poff=0.930, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.109
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.835, poff=0.935, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.110
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.840, poff=0.940, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.111
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.845, poff=0.945, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.111
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.850, poff=0.950, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.112
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.855, poff=0.955, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.113
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.860, poff=0.960, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.113
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.865, poff=0.965, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.114
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.870, poff=0.970, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.115
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.875, poff=0.975, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.115
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.880, poff=0.980, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.116
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.885, poff=0.985, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.117
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.890, poff=0.990, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.117
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.895, poff=0.995, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.118
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.900, poff=1.000, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.119
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.905, poff=1.005, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.119
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.910, poff=1.010, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.120
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.915, poff=1.015, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.121
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.920, poff=1.020, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.121
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.925, poff=1.025, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.122
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.930, poff=1.030, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.122
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.935, poff=1.035, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.123
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.940, poff=1.040, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.124
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.945, poff=1.045, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.124
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.950, poff=1.050, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.125
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.955, poff=1.055, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.126
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.960, poff=1.060, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.126
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.965, poff=1.065, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.127
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.970, poff=1.070, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.128
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.975, poff=1.075, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.128
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.980, poff=1.080, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.129
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.985, poff=1.085, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.130
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.990, poff=1.090, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.000, return probability:0.130
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.995, poff=1.095, profit=0.00000
# DEBUG:uniform:----------------------------------------------------------------------

# %%
print("pon={:.3f}, poff={:.3f}, profit={:.3f}".format(dual_ins.pon, dual_ins.poff, dual_ins.profit))
u_o = 1 / 2 * 1 + 1 / 2 * return_prop * dual_ins.pon * dual_ins.pon - dual_ins.pon - con
u_s = 1 / 2 * (1 - dual_ins.poff) - c
print(u_o, u_s)
# Out:
# pon=0.190, poff=0.290, profit=0.039
# 0.21226703965499996 0.20995

# %%
consumers = np.arange(0, 1, 0.0001)
m =return_prop
pon = 0.35
poff=0.40


if myround(1 / 2 * m * pon * pon - pon + 1 / 2 * poff + c - con) == 0:
    behaviors_tie_online, behaviors_tie_offline = simulate_behavior(consumers=consumers,
                                                                    c=c, con=con, m=m, pon=pon, poff=poff)
    profit_tie_online = cal_profit(m=m, pon=pon, poff=poff, cr=cr, behaviors=behaviors_tie_online)
    profit_tie_offline = cal_profit(m=m, pon=pon, poff=poff, cr=cr, behaviors=behaviors_tie_offline)
    profit = max(profit_tie_online, profit_tie_offline)
else:
    behaviors = simulate_behavior(consumers=consumers, c=c, con=con, m=m, pon=pon, poff=poff)
    profit = cal_profit(m=m, pon=pon, poff=poff, cr=cr, behaviors=behaviors)
# Out:
# DEBUG:uniform:current demand: alpha_o 0.000, alpha_s 0.310, return probability:0.046
# DEBUG:uniform:current demand: online_profit 0.00000, store_profit 0.06200

# %%
Counter([utility_tie_online(loc=x, c=c, con=con, m=return_prop, pon=pon, poff=poff) for x in consumers])
# Out:
# Counter({'l': 6900, 's': 3100})

# %% [markdown]
# ## check

# %%
c=0.11
cr = 0.4
con = 0.02
step = 0.001
density = 0.005
return_prop = 1.8 # if this is a string, it means that we set m=1/(2*pon), which degrades to the baseline model.
dual_ins = dual(c=c, con=con, return_prop=return_prop, cr=cr, step=0.005, density=0.0001)
# Out:
# DEBUG:uniform:current demand: alpha_o 0.960, alpha_s 0.000, return probability:0.000
# DEBUG:uniform:current demand: online_profit 0.00006, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.000, poff=0.020, profit=0.00003
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.950, alpha_s 0.000, return probability:0.009
# DEBUG:uniform:current demand: online_profit 0.00308, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.005, poff=0.025, profit=0.00154
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.940, alpha_s 0.000, return probability:0.018
# DEBUG:uniform:current demand: online_profit 0.00599, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.010, poff=0.030, profit=0.00299
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.930, alpha_s 0.000, return probability:0.027
# DEBUG:uniform:current demand: online_profit 0.00880, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.015, poff=0.035, profit=0.00440
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.920, alpha_s 0.000, return probability:0.036
# DEBUG:uniform:current demand: online_profit 0.01151, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.020, poff=0.040, profit=0.00575
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.911, alpha_s 0.000, return probability:0.045
# DEBUG:uniform:current demand: online_profit 0.01412, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.025, poff=0.045, profit=0.00706
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.901, alpha_s 0.000, return probability:0.054
# DEBUG:uniform:current demand: online_profit 0.01663, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.030, poff=0.050, profit=0.00831
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.892, alpha_s 0.000, return probability:0.063
# DEBUG:uniform:current demand: online_profit 0.01905, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.035, poff=0.055, profit=0.00952
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.883, alpha_s 0.000, return probability:0.072
# DEBUG:uniform:current demand: online_profit 0.02137, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.040, poff=0.060, profit=0.01069
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.873, alpha_s 0.000, return probability:0.081
# DEBUG:uniform:current demand: online_profit 0.02361, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.045, poff=0.065, profit=0.01181
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.864, alpha_s 0.000, return probability:0.090
# DEBUG:uniform:current demand: online_profit 0.02576, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.050, poff=0.070, profit=0.01288
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.855, alpha_s 0.000, return probability:0.099
# DEBUG:uniform:current demand: online_profit 0.02782, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.055, poff=0.075, profit=0.01391
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.846, alpha_s 0.000, return probability:0.108
# DEBUG:uniform:current demand: online_profit 0.02980, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.060, poff=0.080, profit=0.01490
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.837, alpha_s 0.000, return probability:0.117
# DEBUG:uniform:current demand: online_profit 0.03170, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.065, poff=0.085, profit=0.01585
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.829, alpha_s 0.000, return probability:0.126
# DEBUG:uniform:current demand: online_profit 0.03351, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.070, poff=0.090, profit=0.01675
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.820, alpha_s 0.000, return probability:0.135
# DEBUG:uniform:current demand: online_profit 0.03525, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.075, poff=0.095, profit=0.01762
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.811, alpha_s 0.000, return probability:0.144
# DEBUG:uniform:current demand: online_profit 0.03691, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.080, poff=0.100, profit=0.01845
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.803, alpha_s 0.000, return probability:0.153
# DEBUG:uniform:current demand: online_profit 0.03849, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.085, poff=0.105, profit=0.01925
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.794, alpha_s 0.000, return probability:0.162
# DEBUG:uniform:current demand: online_profit 0.04000, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.090, poff=0.110, profit=0.02000
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.786, alpha_s 0.000, return probability:0.171
# DEBUG:uniform:current demand: online_profit 0.04144, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.095, poff=0.115, profit=0.02072
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.778, alpha_s 0.000, return probability:0.180
# DEBUG:uniform:current demand: online_profit 0.04281, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.100, poff=0.120, profit=0.02141
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.770, alpha_s 0.000, return probability:0.189
# DEBUG:uniform:current demand: online_profit 0.04412, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.105, poff=0.125, profit=0.02206
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.762, alpha_s 0.000, return probability:0.198
# DEBUG:uniform:current demand: online_profit 0.04536, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.110, poff=0.130, profit=0.02268
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.754, alpha_s 0.000, return probability:0.207
# DEBUG:uniform:current demand: online_profit 0.04653, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.115, poff=0.135, profit=0.02326
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.746, alpha_s 0.000, return probability:0.216
# DEBUG:uniform:current demand: online_profit 0.04764, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.120, poff=0.140, profit=0.02382
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.738, alpha_s 0.000, return probability:0.225
# DEBUG:uniform:current demand: online_profit 0.04869, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.125, poff=0.145, profit=0.02434
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.730, alpha_s 0.000, return probability:0.234
# DEBUG:uniform:current demand: online_profit 0.04968, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.130, poff=0.150, profit=0.02484
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.723, alpha_s 0.000, return probability:0.243
# DEBUG:uniform:current demand: online_profit 0.05061, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.135, poff=0.155, profit=0.02530
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.715, alpha_s 0.000, return probability:0.252
# DEBUG:uniform:current demand: online_profit 0.05149, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.140, poff=0.160, profit=0.02574
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.708, alpha_s 0.000, return probability:0.261
# DEBUG:uniform:current demand: online_profit 0.05230, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.145, poff=0.165, profit=0.02615
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.700, alpha_s 0.000, return probability:0.270
# DEBUG:uniform:current demand: online_profit 0.05307, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.150, poff=0.170, profit=0.02654
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.693, alpha_s 0.000, return probability:0.279
# DEBUG:uniform:current demand: online_profit 0.05379, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.155, poff=0.175, profit=0.02690
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.686, alpha_s 0.000, return probability:0.288
# DEBUG:uniform:current demand: online_profit 0.05446, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.160, poff=0.180, profit=0.02723
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.679, alpha_s 0.000, return probability:0.297
# DEBUG:uniform:current demand: online_profit 0.05507, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.165, poff=0.185, profit=0.02754
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.672, alpha_s 0.000, return probability:0.306
# DEBUG:uniform:current demand: online_profit 0.05564, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.170, poff=0.190, profit=0.02782
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.665, alpha_s 0.000, return probability:0.315
# DEBUG:uniform:current demand: online_profit 0.05616, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.175, poff=0.195, profit=0.02808
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.658, alpha_s 0.000, return probability:0.324
# DEBUG:uniform:current demand: online_profit 0.05664, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.180, poff=0.200, profit=0.02832
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.651, alpha_s 0.000, return probability:0.333
# DEBUG:uniform:current demand: online_profit 0.05708, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.185, poff=0.205, profit=0.02854
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.645, alpha_s 0.000, return probability:0.342
# DEBUG:uniform:current demand: online_profit 0.05748, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.190, poff=0.210, profit=0.02874
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.638, alpha_s 0.000, return probability:0.351
# DEBUG:uniform:current demand: online_profit 0.05783, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.195, poff=0.215, profit=0.02892
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.632, alpha_s 0.000, return probability:0.360
# DEBUG:uniform:current demand: online_profit 0.05814, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.200, poff=0.220, profit=0.02907
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.625, alpha_s 0.000, return probability:0.369
# DEBUG:uniform:current demand: online_profit 0.05842, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.205, poff=0.225, profit=0.02921
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.619, alpha_s 0.000, return probability:0.378
# DEBUG:uniform:current demand: online_profit 0.05866, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.210, poff=0.230, profit=0.02933
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.613, alpha_s 0.000, return probability:0.387
# DEBUG:uniform:current demand: online_profit 0.05886, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.215, poff=0.235, profit=0.02943
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.607, alpha_s 0.000, return probability:0.396
# DEBUG:uniform:current demand: online_profit 0.05904, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.220, poff=0.240, profit=0.02952
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.601, alpha_s 0.000, return probability:0.405
# DEBUG:uniform:current demand: online_profit 0.05918, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.225, poff=0.245, profit=0.02959
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.595, alpha_s 0.000, return probability:0.414
# DEBUG:uniform:current demand: online_profit 0.05928, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.230, poff=0.250, profit=0.02964
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.589, alpha_s 0.000, return probability:0.423
# DEBUG:uniform:current demand: online_profit 0.05934, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.235, poff=0.255, profit=0.02967
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.584, alpha_s 0.000, return probability:0.432
# DEBUG:uniform:current demand: online_profit 0.05939, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.240, poff=0.260, profit=0.02969
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.578, alpha_s 0.000, return probability:0.441
# DEBUG:uniform:current demand: online_profit 0.05941, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.245, poff=0.265, profit=0.02970
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.572, alpha_s 0.000, return probability:0.450
# DEBUG:uniform:current demand: online_profit 0.05939, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.250, poff=0.270, profit=0.02969
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.567, alpha_s 0.000, return probability:0.459
# DEBUG:uniform:current demand: online_profit 0.05935, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.255, poff=0.275, profit=0.02968
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.561, alpha_s 0.000, return probability:0.468
# DEBUG:uniform:current demand: online_profit 0.05928, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.260, poff=0.280, profit=0.02964
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.556, alpha_s 0.000, return probability:0.477
# DEBUG:uniform:current demand: online_profit 0.05920, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.265, poff=0.285, profit=0.02960
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.551, alpha_s 0.000, return probability:0.486
# DEBUG:uniform:current demand: online_profit 0.05908, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.270, poff=0.290, profit=0.02954
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.546, alpha_s 0.000, return probability:0.495
# DEBUG:uniform:current demand: online_profit 0.05894, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.275, poff=0.295, profit=0.02947
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.541, alpha_s 0.000, return probability:0.504
# DEBUG:uniform:current demand: online_profit 0.05878, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.280, poff=0.300, profit=0.02939
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.536, alpha_s 0.000, return probability:0.513
# DEBUG:uniform:current demand: online_profit 0.05860, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.285, poff=0.305, profit=0.02930
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.531, alpha_s 0.000, return probability:0.522
# DEBUG:uniform:current demand: online_profit 0.05839, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.290, poff=0.310, profit=0.02920
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.526, alpha_s 0.000, return probability:0.531
# DEBUG:uniform:current demand: online_profit 0.05817, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.295, poff=0.315, profit=0.02909
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.522, alpha_s 0.000, return probability:0.540
# DEBUG:uniform:current demand: online_profit 0.05794, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.300, poff=0.320, profit=0.02897
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.517, alpha_s 0.000, return probability:0.549
# DEBUG:uniform:current demand: online_profit 0.05767, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.305, poff=0.325, profit=0.02884
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.513, alpha_s 0.000, return probability:0.558
# DEBUG:uniform:current demand: online_profit 0.05739, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.310, poff=0.330, profit=0.02870
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.508, alpha_s 0.000, return probability:0.567
# DEBUG:uniform:current demand: online_profit 0.05711, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.315, poff=0.335, profit=0.02855
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.504, alpha_s 0.000, return probability:0.576
# DEBUG:uniform:current demand: online_profit 0.05680, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.320, poff=0.340, profit=0.02840
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.500, alpha_s 0.000, return probability:0.585
# DEBUG:uniform:current demand: online_profit 0.05647, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.325, poff=0.345, profit=0.02824
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.496, alpha_s 0.000, return probability:0.594
# DEBUG:uniform:current demand: online_profit 0.05613, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.330, poff=0.350, profit=0.02807
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.492, alpha_s 0.000, return probability:0.603
# DEBUG:uniform:current demand: online_profit 0.05578, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.335, poff=0.355, profit=0.02789
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.488, alpha_s 0.000, return probability:0.612
# DEBUG:uniform:current demand: online_profit 0.05542, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.340, poff=0.360, profit=0.02771
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.484, alpha_s 0.000, return probability:0.621
# DEBUG:uniform:current demand: online_profit 0.05503, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.345, poff=0.365, profit=0.02752
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.480, alpha_s 0.000, return probability:0.630
# DEBUG:uniform:current demand: online_profit 0.05465, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.350, poff=0.370, profit=0.02732
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.477, alpha_s 0.000, return probability:0.639
# DEBUG:uniform:current demand: online_profit 0.05424, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.355, poff=0.375, profit=0.02712
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.473, alpha_s 0.000, return probability:0.648
# DEBUG:uniform:current demand: online_profit 0.05383, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.360, poff=0.380, profit=0.02692
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.470, alpha_s 0.000, return probability:0.657
# DEBUG:uniform:current demand: online_profit 0.05340, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.365, poff=0.385, profit=0.02670
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.466, alpha_s 0.000, return probability:0.666
# DEBUG:uniform:current demand: online_profit 0.05297, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.370, poff=0.390, profit=0.02648
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.463, alpha_s 0.000, return probability:0.675
# DEBUG:uniform:current demand: online_profit 0.05252, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.375, poff=0.395, profit=0.02626
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.460, alpha_s 0.000, return probability:0.684
# DEBUG:uniform:current demand: online_profit 0.05207, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.380, poff=0.400, profit=0.02603
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.457, alpha_s 0.000, return probability:0.693
# DEBUG:uniform:current demand: online_profit 0.05160, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.385, poff=0.405, profit=0.02580
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.454, alpha_s 0.000, return probability:0.702
# DEBUG:uniform:current demand: online_profit 0.05113, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.390, poff=0.410, profit=0.02557
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.451, alpha_s 0.000, return probability:0.711
# DEBUG:uniform:current demand: online_profit 0.05065, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.395, poff=0.415, profit=0.02532
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.448, alpha_s 0.000, return probability:0.720
# DEBUG:uniform:current demand: online_profit 0.05016, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.400, poff=0.420, profit=0.02508
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.445, alpha_s 0.000, return probability:0.729
# DEBUG:uniform:current demand: online_profit 0.04966, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.405, poff=0.425, profit=0.02483
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.443, alpha_s 0.000, return probability:0.738
# DEBUG:uniform:current demand: online_profit 0.04916, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.410, poff=0.430, profit=0.02458
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.440, alpha_s 0.000, return probability:0.747
# DEBUG:uniform:current demand: online_profit 0.04865, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.415, poff=0.435, profit=0.02432
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.437, alpha_s 0.000, return probability:0.756
# DEBUG:uniform:current demand: online_profit 0.04813, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.420, poff=0.440, profit=0.02406
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.435, alpha_s 0.000, return probability:0.765
# DEBUG:uniform:current demand: online_profit 0.04760, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.425, poff=0.445, profit=0.02380
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.433, alpha_s 0.000, return probability:0.774
# DEBUG:uniform:current demand: online_profit 0.04707, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.430, poff=0.450, profit=0.02353
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.430, alpha_s 0.000, return probability:0.783
# DEBUG:uniform:current demand: online_profit 0.04653, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.435, poff=0.455, profit=0.02326
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.428, alpha_s 0.000, return probability:0.792
# DEBUG:uniform:current demand: online_profit 0.04599, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.440, poff=0.460, profit=0.02299
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.426, alpha_s 0.000, return probability:0.801
# DEBUG:uniform:current demand: online_profit 0.04544, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.445, poff=0.465, profit=0.02272
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.424, alpha_s 0.000, return probability:0.810
# DEBUG:uniform:current demand: online_profit 0.04487, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.450, poff=0.470, profit=0.02244
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.423, alpha_s 0.000, return probability:0.819
# DEBUG:uniform:current demand: online_profit 0.04431, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.455, poff=0.475, profit=0.02216
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.421, alpha_s 0.000, return probability:0.828
# DEBUG:uniform:current demand: online_profit 0.04374, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.460, poff=0.480, profit=0.02187
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.419, alpha_s 0.000, return probability:0.837
# DEBUG:uniform:current demand: online_profit 0.04316, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.465, poff=0.485, profit=0.02158
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.417, alpha_s 0.000, return probability:0.846
# DEBUG:uniform:current demand: online_profit 0.04257, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.470, poff=0.490, profit=0.02129
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.416, alpha_s 0.000, return probability:0.855
# DEBUG:uniform:current demand: online_profit 0.04198, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.475, poff=0.495, profit=0.02099
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.415, alpha_s 0.000, return probability:0.864
# DEBUG:uniform:current demand: online_profit 0.04138, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.480, poff=0.500, profit=0.02069
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.413, alpha_s 0.000, return probability:0.873
# DEBUG:uniform:current demand: online_profit 0.04078, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.485, poff=0.505, profit=0.02039
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.412, alpha_s 0.000, return probability:0.882
# DEBUG:uniform:current demand: online_profit 0.04017, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.490, poff=0.510, profit=0.02009
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.411, alpha_s 0.000, return probability:0.891
# DEBUG:uniform:current demand: online_profit 0.03956, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.495, poff=0.515, profit=0.01978
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.410, alpha_s 0.000, return probability:0.900
# DEBUG:uniform:current demand: online_profit 0.03893, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.500, poff=0.520, profit=0.01946
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.409, alpha_s 0.000, return probability:0.909
# DEBUG:uniform:current demand: online_profit 0.03830, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.505, poff=0.525, profit=0.01915
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.408, alpha_s 0.000, return probability:0.918
# DEBUG:uniform:current demand: online_profit 0.03766, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.510, poff=0.530, profit=0.01883
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.407, alpha_s 0.000, return probability:0.927
# DEBUG:uniform:current demand: online_profit 0.03701, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.515, poff=0.535, profit=0.01851
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.407, alpha_s 0.000, return probability:0.936
# DEBUG:uniform:current demand: online_profit 0.03636, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.520, poff=0.540, profit=0.01818
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.406, alpha_s 0.000, return probability:0.945
# DEBUG:uniform:current demand: online_profit 0.03570, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.525, poff=0.545, profit=0.01785
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.406, alpha_s 0.000, return probability:0.954
# DEBUG:uniform:current demand: online_profit 0.03503, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.530, poff=0.550, profit=0.01751
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.405, alpha_s 0.000, return probability:0.963
# DEBUG:uniform:current demand: online_profit 0.03434, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.535, poff=0.555, profit=0.01717
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.405, alpha_s 0.000, return probability:0.972
# DEBUG:uniform:current demand: online_profit 0.03365, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.540, poff=0.560, profit=0.01682
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.405, alpha_s 0.000, return probability:0.981
# DEBUG:uniform:current demand: online_profit 0.03295, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.545, poff=0.565, profit=0.01648
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.405, alpha_s 0.000, return probability:0.990
# DEBUG:uniform:current demand: online_profit 0.03224, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.550, poff=0.570, profit=0.01612
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.404, alpha_s 0.000, return probability:0.999
# DEBUG:uniform:current demand: online_profit 0.03152, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.555, poff=0.575, profit=0.01576
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.404, alpha_s 0.000, return probability:1.008
# DEBUG:uniform:current demand: online_profit 0.03078, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.560, poff=0.580, profit=0.01539
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.405, alpha_s 0.000, return probability:1.017
# DEBUG:uniform:current demand: online_profit 0.03005, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.565, poff=0.585, profit=0.01502
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.405, alpha_s 0.000, return probability:1.026
# DEBUG:uniform:current demand: online_profit 0.02929, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.570, poff=0.590, profit=0.01464
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.405, alpha_s 0.000, return probability:1.035
# DEBUG:uniform:current demand: online_profit 0.02852, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.575, poff=0.595, profit=0.01426
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.406, alpha_s 0.000, return probability:1.044
# DEBUG:uniform:current demand: online_profit 0.02774, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.580, poff=0.600, profit=0.01387
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.406, alpha_s 0.000, return probability:1.053
# DEBUG:uniform:current demand: online_profit 0.02694, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.585, poff=0.605, profit=0.01347
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.406, alpha_s 0.000, return probability:1.062
# DEBUG:uniform:current demand: online_profit 0.02612, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.590, poff=0.610, profit=0.01306
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.407, alpha_s 0.000, return probability:1.071
# DEBUG:uniform:current demand: online_profit 0.02530, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.595, poff=0.615, profit=0.01265
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.408, alpha_s 0.000, return probability:1.080
# DEBUG:uniform:current demand: online_profit 0.02446, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.600, poff=0.620, profit=0.01223
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.409, alpha_s 0.000, return probability:1.089
# DEBUG:uniform:current demand: online_profit 0.02360, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.605, poff=0.625, profit=0.01180
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.410, alpha_s 0.000, return probability:1.098
# DEBUG:uniform:current demand: online_profit 0.02273, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.610, poff=0.630, profit=0.01136
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.411, alpha_s 0.000, return probability:1.107
# DEBUG:uniform:current demand: online_profit 0.02183, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.615, poff=0.635, profit=0.01092
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.412, alpha_s 0.000, return probability:1.116
# DEBUG:uniform:current demand: online_profit 0.02092, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.620, poff=0.640, profit=0.01046
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.413, alpha_s 0.000, return probability:1.125
# DEBUG:uniform:current demand: online_profit 0.01999, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.625, poff=0.645, profit=0.00999
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.414, alpha_s 0.000, return probability:1.134
# DEBUG:uniform:current demand: online_profit 0.01904, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.630, poff=0.650, profit=0.00952
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.416, alpha_s 0.000, return probability:1.143
# DEBUG:uniform:current demand: online_profit 0.01807, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.635, poff=0.655, profit=0.00903
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.417, alpha_s 0.000, return probability:1.152
# DEBUG:uniform:current demand: online_profit 0.01707, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.640, poff=0.660, profit=0.00854
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.419, alpha_s 0.000, return probability:1.161
# DEBUG:uniform:current demand: online_profit 0.01605, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.645, poff=0.665, profit=0.00803
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.420, alpha_s 0.000, return probability:1.170
# DEBUG:uniform:current demand: online_profit 0.01501, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.650, poff=0.670, profit=0.00751
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.422, alpha_s 0.000, return probability:1.179
# DEBUG:uniform:current demand: online_profit 0.01394, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.655, poff=0.675, profit=0.00697
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.424, alpha_s 0.000, return probability:1.188
# DEBUG:uniform:current demand: online_profit 0.01285, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.660, poff=0.680, profit=0.00643
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.426, alpha_s 0.000, return probability:1.197
# DEBUG:uniform:current demand: online_profit 0.01173, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.665, poff=0.685, profit=0.00587
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.428, alpha_s 0.000, return probability:1.206
# DEBUG:uniform:current demand: online_profit 0.01059, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.670, poff=0.690, profit=0.00529
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.430, alpha_s 0.000, return probability:1.215
# DEBUG:uniform:current demand: online_profit 0.00941, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.675, poff=0.695, profit=0.00471
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.432, alpha_s 0.000, return probability:1.224
# DEBUG:uniform:current demand: online_profit 0.00821, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.680, poff=0.700, profit=0.00410
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.435, alpha_s 0.000, return probability:1.233
# DEBUG:uniform:current demand: online_profit 0.00697, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.685, poff=0.705, profit=0.00349
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.437, alpha_s 0.000, return probability:1.242
# DEBUG:uniform:current demand: online_profit 0.00570, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.690, poff=0.710, profit=0.00285
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.439, alpha_s 0.000, return probability:1.251
# DEBUG:uniform:current demand: online_profit 0.00440, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.695, poff=0.715, profit=0.00220
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.442, alpha_s 0.000, return probability:1.260
# DEBUG:uniform:current demand: online_profit 0.00307, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.700, poff=0.720, profit=0.00153
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.445, alpha_s 0.000, return probability:1.269
# DEBUG:uniform:current demand: online_profit 0.00170, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.705, poff=0.725, profit=0.00085
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.447, alpha_s 0.000, return probability:1.278
# DEBUG:uniform:current demand: online_profit 0.00029, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.710, poff=0.730, profit=0.00014
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.450, alpha_s 0.000, return probability:1.287
# DEBUG:uniform:current demand: online_profit -0.00116, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.715, poff=0.735, profit=-0.00058
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.453, alpha_s 0.000, return probability:1.296
# DEBUG:uniform:current demand: online_profit -0.00264, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.720, poff=0.740, profit=-0.00132
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.456, alpha_s 0.000, return probability:1.305
# DEBUG:uniform:current demand: online_profit -0.00416, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.725, poff=0.745, profit=-0.00208
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.459, alpha_s 0.000, return probability:1.314
# DEBUG:uniform:current demand: online_profit -0.00573, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.730, poff=0.750, profit=-0.00286
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.462, alpha_s 0.000, return probability:1.323
# DEBUG:uniform:current demand: online_profit -0.00734, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.735, poff=0.755, profit=-0.00367
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.466, alpha_s 0.000, return probability:1.332
# DEBUG:uniform:current demand: online_profit -0.00899, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.740, poff=0.760, profit=-0.00450
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.469, alpha_s 0.000, return probability:1.341
# DEBUG:uniform:current demand: online_profit -0.01069, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.745, poff=0.765, profit=-0.00535
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.472, alpha_s 0.000, return probability:1.350
# DEBUG:uniform:current demand: online_profit -0.01244, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.750, poff=0.770, profit=-0.00622
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.476, alpha_s 0.000, return probability:1.359
# DEBUG:uniform:current demand: online_profit -0.01423, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.755, poff=0.775, profit=-0.00712
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.480, alpha_s 0.000, return probability:1.368
# DEBUG:uniform:current demand: online_profit -0.01608, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.760, poff=0.780, profit=-0.00804
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.483, alpha_s 0.000, return probability:1.377
# DEBUG:uniform:current demand: online_profit -0.01797, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.765, poff=0.785, profit=-0.00899
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.487, alpha_s 0.000, return probability:1.386
# DEBUG:uniform:current demand: online_profit -0.01992, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.770, poff=0.790, profit=-0.00996
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.491, alpha_s 0.000, return probability:1.395
# DEBUG:uniform:current demand: online_profit -0.02193, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.775, poff=0.795, profit=-0.01096
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.495, alpha_s 0.000, return probability:1.404
# DEBUG:uniform:current demand: online_profit -0.02399, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.780, poff=0.800, profit=-0.01199
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.499, alpha_s 0.000, return probability:1.413
# DEBUG:uniform:current demand: online_profit -0.02610, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.785, poff=0.805, profit=-0.01305
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.503, alpha_s 0.000, return probability:1.422
# DEBUG:uniform:current demand: online_profit -0.02828, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.790, poff=0.810, profit=-0.01414
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.508, alpha_s 0.000, return probability:1.431
# DEBUG:uniform:current demand: online_profit -0.03051, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.795, poff=0.815, profit=-0.01526
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.512, alpha_s 0.000, return probability:1.440
# DEBUG:uniform:current demand: online_profit -0.03281, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.800, poff=0.820, profit=-0.01640
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.516, alpha_s 0.000, return probability:1.449
# DEBUG:uniform:current demand: online_profit -0.03518, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.805, poff=0.825, profit=-0.01759
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.521, alpha_s 0.000, return probability:1.458
# DEBUG:uniform:current demand: online_profit -0.03760, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.810, poff=0.830, profit=-0.01880
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.526, alpha_s 0.000, return probability:1.467
# DEBUG:uniform:current demand: online_profit -0.04010, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.815, poff=0.835, profit=-0.02005
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.530, alpha_s 0.000, return probability:1.476
# DEBUG:uniform:current demand: online_profit -0.04267, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.820, poff=0.840, profit=-0.02133
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.535, alpha_s 0.000, return probability:1.485
# DEBUG:uniform:current demand: online_profit -0.04530, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.825, poff=0.845, profit=-0.02265
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.540, alpha_s 0.000, return probability:1.494
# DEBUG:uniform:current demand: online_profit -0.04801, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.830, poff=0.850, profit=-0.02401
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.545, alpha_s 0.000, return probability:1.503
# DEBUG:uniform:current demand: online_profit -0.05080, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.835, poff=0.855, profit=-0.02540
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.550, alpha_s 0.000, return probability:1.512
# DEBUG:uniform:current demand: online_profit -0.05365, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.840, poff=0.860, profit=-0.02682
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.555, alpha_s 0.000, return probability:1.521
# DEBUG:uniform:current demand: online_profit -0.05659, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.845, poff=0.865, profit=-0.02830
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.561, alpha_s 0.000, return probability:1.530
# DEBUG:uniform:current demand: online_profit -0.05961, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.850, poff=0.870, profit=-0.02981
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.566, alpha_s 0.000, return probability:1.539
# DEBUG:uniform:current demand: online_profit -0.06271, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.855, poff=0.875, profit=-0.03135
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.571, alpha_s 0.000, return probability:1.548
# DEBUG:uniform:current demand: online_profit -0.06589, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.860, poff=0.880, profit=-0.03294
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.577, alpha_s 0.000, return probability:1.557
# DEBUG:uniform:current demand: online_profit -0.06917, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.865, poff=0.885, profit=-0.03458
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.583, alpha_s 0.000, return probability:1.566
# DEBUG:uniform:current demand: online_profit -0.07252, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.870, poff=0.890, profit=-0.03626
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.588, alpha_s 0.000, return probability:1.575
# DEBUG:uniform:current demand: online_profit -0.07597, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.875, poff=0.895, profit=-0.03798
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.594, alpha_s 0.000, return probability:1.584
# DEBUG:uniform:current demand: online_profit -0.07951, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.880, poff=0.900, profit=-0.03975
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.600, alpha_s 0.000, return probability:1.593
# DEBUG:uniform:current demand: online_profit -0.08314, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.885, poff=0.905, profit=-0.04157
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.606, alpha_s 0.000, return probability:1.602
# DEBUG:uniform:current demand: online_profit -0.08688, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.890, poff=0.910, profit=-0.04344
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.612, alpha_s 0.000, return probability:1.611
# DEBUG:uniform:current demand: online_profit -0.09070, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.895, poff=0.915, profit=-0.04535
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.618, alpha_s 0.000, return probability:1.620
# DEBUG:uniform:current demand: online_profit -0.09463, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.900, poff=0.920, profit=-0.04731
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.624, alpha_s 0.000, return probability:1.629
# DEBUG:uniform:current demand: online_profit -0.09865, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.905, poff=0.925, profit=-0.04933
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.631, alpha_s 0.000, return probability:1.638
# DEBUG:uniform:current demand: online_profit -0.10280, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.910, poff=0.930, profit=-0.05140
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.637, alpha_s 0.000, return probability:1.647
# DEBUG:uniform:current demand: online_profit -0.10703, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.915, poff=0.935, profit=-0.05352
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.644, alpha_s 0.000, return probability:1.656
# DEBUG:uniform:current demand: online_profit -0.11138, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.920, poff=0.940, profit=-0.05569
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.650, alpha_s 0.000, return probability:1.665
# DEBUG:uniform:current demand: online_profit -0.11584, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.925, poff=0.945, profit=-0.05792
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.657, alpha_s 0.000, return probability:1.674
# DEBUG:uniform:current demand: online_profit -0.12042, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.930, poff=0.950, profit=-0.06021
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.664, alpha_s 0.000, return probability:1.683
# DEBUG:uniform:current demand: online_profit -0.12511, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.935, poff=0.955, profit=-0.06256
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.671, alpha_s 0.000, return probability:1.692
# DEBUG:uniform:current demand: online_profit -0.12993, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.940, poff=0.960, profit=-0.06496
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.677, alpha_s 0.000, return probability:1.701
# DEBUG:uniform:current demand: online_profit -0.13484, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.945, poff=0.965, profit=-0.06742
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.685, alpha_s 0.000, return probability:1.710
# DEBUG:uniform:current demand: online_profit -0.13990, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.950, poff=0.970, profit=-0.06995
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.692, alpha_s 0.000, return probability:1.719
# DEBUG:uniform:current demand: online_profit -0.14507, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.955, poff=0.975, profit=-0.07254
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.699, alpha_s 0.000, return probability:1.728
# DEBUG:uniform:current demand: online_profit -0.15039, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.960, poff=0.980, profit=-0.07519
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.706, alpha_s 0.000, return probability:1.737
# DEBUG:uniform:current demand: online_profit -0.15582, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.965, poff=0.985, profit=-0.07791
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.714, alpha_s 0.000, return probability:1.746
# DEBUG:uniform:current demand: online_profit -0.16138, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.970, poff=0.990, profit=-0.08069
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.721, alpha_s 0.000, return probability:1.755
# DEBUG:uniform:current demand: online_profit -0.16708, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.975, poff=0.995, profit=-0.08354
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.729, alpha_s 0.000, return probability:1.764
# DEBUG:uniform:current demand: online_profit -0.17292, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.980, poff=1.000, profit=-0.08646
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.737, alpha_s 0.000, return probability:1.773
# DEBUG:uniform:current demand: online_profit -0.17891, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.985, poff=1.005, profit=-0.08945
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.744, alpha_s 0.000, return probability:1.782
# DEBUG:uniform:current demand: online_profit -0.18504, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.990, poff=1.010, profit=-0.09252
# DEBUG:uniform:----------------------------------------------------------------------
# DEBUG:uniform:current demand: alpha_o 0.752, alpha_s 0.000, return probability:1.791
# DEBUG:uniform:current demand: online_profit -0.19131, store_profit 0.00000
# DEBUG:uniform:current loop: pon=0.995, poff=1.015, profit=-0.09566
# DEBUG:uniform:----------------------------------------------------------------------

# %%
print("pon={:.3f}, poff={:.3f}, profit={:.3f}, return probability :{}".format(dual_ins.pon, dual_ins.poff, dual_ins.profit, return_prop * dual_ins.pon))
u_o = 1 / 2 * 1 + 1 / 2 * return_prop * dual_ins.pon * dual_ins.pon - dual_ins.pon - con
u_s = 1 / 2 * (1 - dual_ins.poff) - c
print(u_o-u_s, np.isclose(u_o, u_s))
# Out:
# pon=0.245, poff=0.265, profit=0.030, return probability :0.44117999999999996
# 0.03151660900000003 False
